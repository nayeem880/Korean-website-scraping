# %% [markdown]
# # Parent Link Extraction

# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

# %%
url = "https://class101.net/creative"
base = "https://class101.net"

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title data-react-helmet="true">
#    클래스101 | 준비물까지 챙겨주는 온라인 클래스
#   </title>
#   <meta content="클래스101" data-react-helmet="true" name="name"/>
#   <meta data-react-helmet="true" name="author"/>
#   <meta content="대한민국 1등 온라인 클래스 플랫폼. 준비물까지 모두 챙겨드릴게요. 해야만 하는 일에 밀려, 방법을 몰라서, 시작을 망설였다면, 사랑하는 일을 하기 위한 기반이 필요하다면, 당신이 사랑하는 일을 하며 살수 있도록 1,000명 이상의 크리에이터와 함께 취미도, 직무도, 경제적인 자유도 클래스101에서 시작을 함께하세요." data-react-helmet="true" name="description"/>
#   <meta data-react-helmet="true" property="keywords"/>
#   <meta content="클래스101" data-react-helmet="true" property="og:site_name"/>
#   <meta content="준비물까지 챙겨주는 온라인 클래스" data-react-helmet="true" property="og:title"/>
#   <meta content="https://class101.net/creative" data-react-helmet="true" property="og:url"/>
#   <meta content="대한민국 1등 온라인 클래스 플랫폼. 준비물까지 모두 챙겨드릴게요. 해야만 하는 일에 밀려, 방법을 몰라서, 시작을 망설였다면, 사랑하는 일을 하기 위한 기반이 필요하다면, 당신이 사랑하는 일을 하며 살수 있도록 1,000명 이상의 크리에이터와 함께 취미도, 직무도, 경제적인 자유도 클래스101에서 시작을 함께하세요." data-react-helmet="true" property="og:description"/>
#   <meta content="https://class101.net/images/og-image.png" data-react-helmet="true" property="og:image"/>
#   <meta content="1200" data-react-helmet="true" property="og:image:width"/>
#   <meta content="630" data-react-helmet="true" property="og:image:height"/>
#   <meta content="https://class101.net/images/og-image.png" data-react-helmet="true" name="twitter:image"/>
#   <meta content="summary_large_image" data-react-helmet="true" name="twitter:card"/>
#   <meta data-react-helmet="true" name="twitter:creator"/>
#   <meta content="준비물까지 챙겨주는 온라인 클래스" data-react-helmet="true" name="twitter:title"/>
#   <meta content="대한민국 1등 온라인 클래스 플랫폼. 준비물까지 모두 챙겨드릴게요. 해야만 하는 일에 밀려, 방법을 몰라서, 시작을 망설였다면, 사랑하는 일을 하기 위한 기반이 필요하다면, 당신이 사랑하는 일을 하며 살수 있도록 1,000명 이상의 크리에이터와 함께 취미도, 직무도, 경제적인 자유도 클래스101에서 시작을 함께하세요." data-react-helmet="true" name="twitter:description"/>
#   <meta content="Written By" data-react-helmet="true" name="twitter:label1"/>
#   <meta data-react-helmet="true" name="twitter:data1"/>
#   <meta content="web" data-react-helmet="true" name="environment"/>
#   <meta data-react-helmet="true" name="fb:app_id"/>
#   <link data-react-helmet="true" href="https://class101.net/creative" rel="canonical"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="149966138967961" property="fb:app_id"/>
#   <link href="/images/manifest.json" rel="manifest"/>
#   <link href="/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/images/favicon-48x48.png" rel="icon" sizes="48x48" type="image/png"/>
#   <link href="/images/favicon-57x57.png" rel="icon" sizes="57x57" type="image/png"/>
#   <link href="/images/favicon-64x64.png" rel="icon" sizes="64x64" type="image/png"/>
#   <link href="/images/favicon-72x72.png" rel="icon" sizes="72x72" type="image/png"/>
#   <link href="/images/favicon-120x120.png" rel="icon" sizes="120x120" type="image/png"/>
#   <link href="/images/favicon-152x152.png" rel="icon" sizes="152x152" type="image/png"/>
#   <link href="/images/site.webmanifest" rel="manifest"/>
#   <meta content="#000000" name="msapplication-TileColor"/>
#   <meta content="#000000" name="theme-color"/>
#   <style data-styled="" data-styled-version="5.2.0">
#    .swiper-container{margin:0 auto;position:relative;overflow:hidden;list-style:none;padding:0;z-index:1;}/*!sc*/
# .swiper-container-no-flexbox .swiper-slide{float:left;}/*!sc*/
# .swiper-container-vertical > .swiper-wrapper{-webkit-box-orient:vertical;-webkit-box-direction:normal;-webkit-flex-direction:column;-ms-flex-direction:column;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .swiper-wrapper{position:relative;width:100%;height:100%;z-index:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;transition-property:-webkit-transform;-o-transition-property:transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;-webkit-transition-property:-webkit-transform,-webkit-transform;-webkit-transition-property:transform,-webkit-transform;transition-property:transform,-webkit-transform;-webkit-box-sizing:content-box;box-sizing:content-box;}/*!sc*/
# .swiper-container-android .swiper-slide,.swiper-wrapper{-webkit-transform:translate3d(0px,0,0);-webkit-transform:translate3d(0px,0,0);-ms-transform:translate3d(0px,0,0);transform:translate3d(0px,0,0);}/*!sc*/
# .swiper-container-multirow > .swiper-wrapper{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .swiper-container-free-mode > .swiper-wrapper{-webkit-transition-timing-function:ease-out;-o-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;margin:0 auto;}/*!sc*/
# .swiper-slide{-webkit-flex-shrink:0;-ms-flex-negative:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:100%;height:100%;position:relative;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;transition-property:-webkit-transform;-o-transition-property:transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;-webkit-transition-property:-webkit-transform,-webkit-transform;-webkit-transition-property:transform,-webkit-transform;transition-property:transform,-webkit-transform;}/*!sc*/
# .swiper-slide-invisible-blank{visibility:hidden;}/*!sc*/
# .swiper-container-autoheight,.swiper-container-autoheight .swiper-slide{height:auto;}/*!sc*/
# .swiper-container-autoheight .swiper-wrapper{-webkit-box-align:start;-webkit-align-items:flex-start;-ms-flex-align:start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition-property:height,-webkit-transform;-webkit-transition-property:height,-webkit-transform;-webkit-transition-property:height,-webkit-transform;transition-property:height,-webkit-transform;-o-transition-property:transform,height;-webkit-transition-property:-webkit-transform,height;-webkit-transition-property:transform,height;transition-property:transform,height;-webkit-transition-property:-webkit-transform,height,-webkit-transform;-webkit-transition-property:transform,height,-webkit-transform;transition-property:transform,height,-webkit-transform;}/*!sc*/
# .swiper-container-wp8-horizontal,.swiper-container-wp8-horizontal > .swiper-wrapper{-ms-touch-action:pan-y;touch-action:pan-y;}/*!sc*/
# .swiper-container-wp8-vertical,.swiper-container-wp8-vertical > .swiper-wrapper{-ms-touch-action:pan-x;touch-action:pan-x;}/*!sc*/
# .swiper-button-prev,.swiper-button-next{position:absolute;top:50%;width:27px;height:44px;margin-top:-22px;z-index:10;cursor:pointer;background-size:27px 44px;background-position:center;background-repeat:no-repeat;}/*!sc*/
# .swiper-button-prev.swiper-button-disabled,.swiper-button-next.swiper-button-disabled{opacity:0.35;cursor:auto;pointer-events:none;}/*!sc*/
# .swiper-button-lock{display:none;}/*!sc*/
# .swiper-pagination{position:absolute;text-align:center;-webkit-transition:300ms opacity;-o-transition:300ms opacity;-webkit-transition:300ms opacity;transition:300ms opacity;-webkit-transform:translate3d(0,0,0);-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);z-index:10;pointer-events:none;}/*!sc*/
# .swiper-pagination.swiper-pagination-hidden{opacity:0;}/*!sc*/
# .swiper-pagination-fraction,.swiper-pagination-custom,.swiper-container-horizontal > .swiper-pagination-bullets{bottom:10px;left:0;width:100%;}/*!sc*/
# .swiper-pagination-bullets-dynamic{overflow:hidden;font-size:0;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);position:relative;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active{-webkit-transform:scale(1);-ms-transform:scale(1);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-main{-webkit-transform:scale(1);-ms-transform:scale(1);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev{-webkit-transform:scale(0.66);-ms-transform:scale(0.66);-webkit-transform:scale(0.66);-ms-transform:scale(0.66);transform:scale(0.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev-prev{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next{-webkit-transform:scale(0.66);-ms-transform:scale(0.66);-webkit-transform:scale(0.66);-ms-transform:scale(0.66);transform:scale(0.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next-next{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);}/*!sc*/
# .swiper-pagination-bullet{width:8px;height:8px;display:inline-block;border-radius:100%;background:#000;opacity:0.2;pointer-events:auto;}/*!sc*/
# button.swiper-pagination-bullet{border:none;margin:0;padding:0;-webkit-box-shadow:none;box-shadow:none;-webkit-appearance:none;-moz-appearance:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .swiper-pagination-clickable .swiper-pagination-bullet{cursor:pointer;}/*!sc*/
# .swiper-pagination-bullet-active{opacity:1;background:#007aff;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets{right:10px;top:50%;-webkit-transform:translate3d(0px,-50%,0);-webkit-transform:translate3d(0px,-50%,0);-ms-transform:translate3d(0px,-50%,0);transform:translate3d(0px,-50%,0);}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets .swiper-pagination-bullet{margin:6px 0;display:block;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic{top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);width:8px;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic .swiper-pagination-bullet{display:inline-block;-webkit-transition:200ms top,200ms -webkit-transform;-webkit-transition:200ms top,200ms -webkit-transform;-webkit-transition:200ms top,200ms -webkit-transform;transition:200ms top,200ms -webkit-transform;-o-transition:200ms transform,200ms top;-webkit-transition:200ms -webkit-transform,200ms top;-webkit-transition:200ms transform,200ms top;transition:200ms transform,200ms top;-webkit-transition:200ms -webkit-transform,200ms top,200ms -webkit-transform;-webkit-transition:200ms transform,200ms top,200ms -webkit-transform;transition:200ms transform,200ms top,200ms -webkit-transform;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets .swiper-pagination-bullet{margin:0 4px;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic{left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);white-space:nowrap;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transition:200ms left,200ms -webkit-transform;-webkit-transition:200ms left,200ms -webkit-transform;-webkit-transition:200ms left,200ms -webkit-transform;transition:200ms left,200ms -webkit-transform;-o-transition:200ms transform,200ms left;-webkit-transition:200ms -webkit-transform,200ms left;-webkit-transition:200ms transform,200ms left;transition:200ms transform,200ms left;-webkit-transition:200ms -webkit-transform,200ms left,200ms -webkit-transform;-webkit-transition:200ms transform,200ms left,200ms -webkit-transform;transition:200ms transform,200ms left,200ms -webkit-transform;}/*!sc*/
# .swiper-container-horizontal.swiper-container-rtl > .swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transition:200ms right,200ms -webkit-transform;-webkit-transition:200ms right,200ms -webkit-transform;-webkit-transition:200ms right,200ms -webkit-transform;transition:200ms right,200ms -webkit-transform;-o-transition:200ms transform,200ms right;-webkit-transition:200ms -webkit-transform,200ms right;-webkit-transition:200ms transform,200ms right;transition:200ms transform,200ms right;-webkit-transition:200ms -webkit-transform,200ms right,200ms -webkit-transform;-webkit-transition:200ms transform,200ms right,200ms -webkit-transform;transition:200ms transform,200ms right,200ms -webkit-transform;}/*!sc*/
# .swiper-pagination-white .swiper-pagination-bullet-active{background:#ffffff;}/*!sc*/
# .swiper-pagination-black .swiper-pagination-bullet-active{background:#000000;}/*!sc*/
# .swiper-pagination-lock{display:none;}/*!sc*/
# .swiper-container .swiper-notification{position:absolute;left:0;top:0;pointer-events:none;opacity:0;z-index:-1000;}/*!sc*/
# .swiper-container-fade.swiper-container-free-mode .swiper-slide{-webkit-transition-timing-function:ease-out;-o-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;}/*!sc*/
# .swiper-container-fade .swiper-slide{pointer-events:none;-webkit-transition-property:opacity;-o-transition-property:opacity;-webkit-transition-property:opacity;transition-property:opacity;}/*!sc*/
# .swiper-container-fade .swiper-slide .swiper-slide{pointer-events:none;}/*!sc*/
# .swiper-container-fade .swiper-slide-active,.swiper-container-fade .swiper-slide-active .swiper-slide-active{pointer-events:auto;}/*!sc*/
# .swiper-container-coverflow .swiper-wrapper{-ms-perspective:1200px;}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# p,ul{padding:0;margin:0;}/*!sc*/
# data-styled.g1[id="sc-global-kTfdpC1"]{content:"sc-global-kTfdpC1,"}/*!sc*/
# .bVtFQj{font-size:32px;font-weight:bold;color:#FFF;line-height:44px;-webkit-letter-spacing:-0.6px;-moz-letter-spacing:-0.6px;-ms-letter-spacing:-0.6px;letter-spacing:-0.6px;margin:0;margin:0;}/*!sc*/
# @media (max-width:1023px){.bVtFQj{font-size:24px;font-weight:bold;color:#FFF;line-height:34px;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;margin:0;margin:0;}}/*!sc*/
# .besvtM{font-size:16px;font-weight:normal;color:#FFF;line-height:24px;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;margin:0;margin:0;}/*!sc*/
# @media (max-width:1023px){.besvtM{font-size:14px;font-weight:normal;color:#FFF;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}}/*!sc*/
# .cAQlab{font-size:20px;font-weight:bold;color:#1b1c1d;line-height:28px;margin:0;margin:0;}/*!sc*/
# @media (max-width:1023px){.cAQlab{font-size:18px;font-weight:bold;color:#1b1c1d;line-height:24px;-webkit-letter-spacing:-0.45px;-moz-letter-spacing:-0.45px;-ms-letter-spacing:-0.45px;letter-spacing:-0.45px;margin:0;margin:0;}}/*!sc*/
# @media (min-width:1024px){.cAQlab{font-size:24px;font-weight:bold;color:#1b1c1d;line-height:34px;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;margin:0;margin:0;}}/*!sc*/
# .cgorFR{font-size:9px;font-weight:600;color:#1b1c1d;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# @media (min-width:1024px){.cgorFR{font-size:11px;font-weight:600;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}}/*!sc*/
# .kiVvlk{font-size:11px;font-weight:normal;color:#858a8d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# .joKiRU{font-size:11px;font-weight:normal;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# .biNtgO{font-size:14px;font-weight:bold;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}/*!sc*/
# .bQhOjs{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}/*!sc*/
# data-styled.g2[id="sc-bdnylx"]{content:"bVtFQj,besvtM,cAQlab,cgorFR,kiVvlk,joKiRU,biNtgO,bQhOjs,"}/*!sc*/
# .cuIYFB{display:block;}/*!sc*/
# data-styled.g4[id="sc-dlnjPT"]{content:"cuIYFB,"}/*!sc*/
# .kQHvAX{min-width:20px;height:20px;border-radius:3px;padding-left:6px;padding-right:6px;background-color:#f8f8f9;-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;}/*!sc*/
# .kQHvAX svg{width:12px;height:12px;}/*!sc*/
# data-styled.g9[id="sc-iCoHVE"]{content:"kQHvAX,"}/*!sc*/
# .heQMBE{font-size:9px;font-weight:normal;color:#f33340;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;color:#f33340;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .klsxCA{font-size:9px;font-weight:normal;color:#858a8d;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;color:#858a8d;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g11[id="sc-pNWxx"]{content:"heQMBE,klsxCA,"}/*!sc*/
# .fJNMMN{-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0;width:18px;height:18px;margin-right:4px;}/*!sc*/
# data-styled.g17[id="sc-bqGHjH"]{content:"fJNMMN,"}/*!sc*/
# .dyNqkJ{border:0;outline:none;box-sizing:border-box;margin:0;padding:0;-webkit-flex:initial;-ms-flex:initial;flex:initial;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .dyNqkJ:not(:disabled):not(.disabled){cursor:pointer;}/*!sc*/
# .dyNqkJ.disabled{cursor:not-allowed;}/*!sc*/
# data-styled.g18[id="sc-ksluoS"]{content:"dyNqkJ,"}/*!sc*/
# .liuvoF{-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g19[id="sc-hBMVcZ"]{content:"liuvoF,"}/*!sc*/
# .aqTZb{margin:0;padding:0;-webkit-flex:initial;-ms-flex:initial;flex:initial;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .aqTZb:not(:disabled):not(.disabled){cursor:pointer;}/*!sc*/
# .aqTZb.disabled{cursor:not-allowed;}/*!sc*/
# .aqTZb.disabled{cursor:not-allowed;}/*!sc*/
# data-styled.g20[id="sc-fnVYJo"]{content:"aqTZb,"}/*!sc*/
# .goHICw{width:100%;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .disabled .sc-fFSRdu{pointer-events:none;}/*!sc*/
# data-styled.g21[id="sc-fFSRdu"]{content:"goHICw,"}/*!sc*/
# .dEOcBP{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;vertical-align:middle;border-radius:3px;color:#1b1c1d;background-color:#f8f8f9;font-weight:500;font-size:14px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;padding:0 16px;height:40px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .dEOcBP > a{color:#1b1c1d;}/*!sc*/
# .dEOcBP:hover,.dEOcBP:active{background-color:#dddde1;}/*!sc*/
# .dEOcBP.disabled{color:#dde0e2;background-color:#f8f8f9;}/*!sc*/
# data-styled.g27[id="sc-kfYqjs"]{content:"dEOcBP,"}/*!sc*/
# .ljsIML{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex:none;-ms-flex:none;flex:none;vertical-align:middle;padding:0;border-radius:3px;color:#1b1c1d;background-color:transparent;width:32px;height:32px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;}/*!sc*/
# .ljsIML:hover,.ljsIML:active{background-color:rgba(248,248,249,0.2);-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .ljsIML.disabled{color:#dde0e2;background-color:transparent;}/*!sc*/
# .kUvwKv{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex:none;-ms-flex:none;flex:none;vertical-align:middle;padding:0;border-radius:3px;color:#3e4042;background-color:#FFF;width:32px;height:32px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;}/*!sc*/
# .kUvwKv:hover,.kUvwKv:active{background-color:#e6e6e6;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .kUvwKv.disabled{color:#dde0e2;background-color:#FFF;}/*!sc*/
# data-styled.g28[id="sc-fKgIGh"]{content:"ljsIML,kUvwKv,"}/*!sc*/
# .cRAuSD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:middle;background:none;color:#a8aeb3;font-size:14px;font-weight:500;line-height:20px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;-webkit-transition:color 0.1s;transition:color 0.1s;}/*!sc*/
# .cRAuSD > a{color:#a8aeb3;}/*!sc*/
# .cRAuSD:not(.disabled):hover,.cRAuSD:not(.disabled):active{color:#8d959b;-webkit-text-decoration-line:underline;text-decoration-line:underline;}/*!sc*/
# .cRAuSD:not(.disabled):hover > a,.cRAuSD:not(.disabled):active > a{color:#8d959b;-webkit-text-decoration-line:underline;text-decoration-line:underline;}/*!sc*/
# .cRAuSD.disabled{color:#dde0e2;}/*!sc*/
# data-styled.g29[id="sc-bCwgka"]{content:"cRAuSD,"}/*!sc*/
# .cYmwOA{position:relative;width:100%;}/*!sc*/
# data-styled.g36[id="sc-bYwzba"]{content:"cYmwOA,"}/*!sc*/
# .cgnnmn{overflow:hidden;border-radius:3px;margin-bottom:8px;}/*!sc*/
# data-styled.g37[id="sc-kLokih"]{content:"cgnnmn,"}/*!sc*/
# .kDJUBe{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;color:#1b1c1d;height:40px;overflow:hidden;margin-bottom:6px;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;}/*!sc*/
# data-styled.g40[id="sc-hiKfjK"]{content:"kDJUBe,"}/*!sc*/
# .EIIkt{margin-bottom:4px;margin-top:4px;}/*!sc*/
# data-styled.g41[id="sc-gXfWUo"]{content:"EIIkt,"}/*!sc*/
# .jtftyQ.swiper-button-prev,.jtftyQ.swiper-button-next{box-shadow:0px 1px 3px rgba(41,42,43,0.1),0px 0px 0.5px rgba(0,0,0,0.04);width:32px;height:32px;background-image:none;margin:0;position:absolute;top:0;left:auto;}/*!sc*/
# .jtftyQ.swiper-button-prev:focus,.jtftyQ.swiper-button-next:focus{outline:none;}/*!sc*/
# .jtftyQ.swiper-button-prev:not(.swiper-button-disabled):active,.jtftyQ.swiper-button-next:not(.swiper-button-disabled):active{opacity:1;pointer-events:auto;}/*!sc*/
# .jtftyQ.swiper-button-prev.swiper-button-disabled,.jtftyQ.swiper-button-next.swiper-button-disabled{pointer-events:auto;cursor:not-allowed;}/*!sc*/
# .jtftyQ.swiper-button-prev{right:32px;border-top-right-radius:0;border-bottom-right-radius:0;}/*!sc*/
# .jtftyQ.swiper-button-next{right:0;border-top-left-radius:0;border-bottom-left-radius:0;}/*!sc*/
# data-styled.g44[id="sc-jcwofb"]{content:"jtftyQ,"}/*!sc*/
# .diWYkf{background-color:#edeff0;border-radius:3px;border-radius:50%;-webkit-animation:hllEEO 1s infinite linear alternate;animation:hllEEO 1s infinite linear alternate;}/*!sc*/
# .jVbcIg{background-color:#edeff0;border-radius:3px;-webkit-animation:hllEEO 1s infinite linear alternate;animation:hllEEO 1s infinite linear alternate;}/*!sc*/
# data-styled.g90[id="sc-bXevSJ"]{content:"diWYkf,jVbcIg,"}/*!sc*/
# .bokBDO{opacity:0;}/*!sc*/
# data-styled.g91[id="sc-eGJXgd"]{content:"bokBDO,"}/*!sc*/
# .eXqyOM{overflow:hidden;}/*!sc*/
# data-styled.g169[id="sc-kHVJdr"]{content:"eXqyOM,"}/*!sc*/
# .kbVVcN{overflow:hidden;list-style:none;margin:0;padding:0;margin-right:-12px;margin-left:-12px;margin-bottom:-32px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-content:stretch;-ms-flex-line-pack:stretch;align-content:stretch;}/*!sc*/
# @media (max-width:1023px){.kbVVcN{margin-right:-4px;margin-left:-4px;margin-bottom:-24px;margin-right:-8px;margin-left:-8px;}}/*!sc*/
# data-styled.g170[id="sc-ktvXtq"]{content:"kbVVcN,"}/*!sc*/
# .lchZaB{position:relative;min-height:1px;padding-right:12px;padding-left:12px;margin-bottom:32px;box-sizing:border-box;width:50%;}/*!sc*/
# @media (max-width:1023px){.lchZaB{padding-right:4px;padding-left:4px;margin-bottom:24px;padding-right:8px;padding-left:8px;}}/*!sc*/
# @media (min-width:1024px){.lchZaB{width:25%;}}/*!sc*/
# data-styled.g171[id="sc-gXZlrW"]{content:"lchZaB,"}/*!sc*/
# .bhFDDX{margin-left:24px;font-weight:bold;color:#858a8d;}/*!sc*/
# .bhFDDX > a{color:#858a8d;}/*!sc*/
# @media (max-width:1023px){.bhFDDX{display:none;}}/*!sc*/
# data-styled.g172[id="sc-bFSanr"]{content:"bhFDDX,"}/*!sc*/
# .gpgOkp{-webkit-transition:opacity 150ms ease-in-out;transition:opacity 150ms ease-in-out;opacity:0;}/*!sc*/
# @media (max-width:1023px){.gpgOkp{opacity:1;}.gpgOkp path{fill:#cdd1d4;}}/*!sc*/
# data-styled.g173[id="sc-fxFQrc"]{content:"gpgOkp,"}/*!sc*/
# .eEZxYO{margin-bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .eEZxYO a{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .eEZxYO a:hover .sc-fxFQrc{opacity:1;}/*!sc*/
# .hFlIMl{margin-bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}/*!sc*/
# .hFlIMl a{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .hFlIMl a:hover .sc-fxFQrc{opacity:1;}/*!sc*/
# data-styled.g175[id="sc-cjzMPC"]{content:"eEZxYO,hFlIMl,"}/*!sc*/
# .hnEsJG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g176[id="sc-igOljT"]{content:"hnEsJG,"}/*!sc*/
# .faHGve{font-size:14px;font-weight:normal;color:#858a8d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin-top:4px;}/*!sc*/
# data-styled.g177[id="sc-JgrOI"]{content:"faHGve,"}/*!sc*/
# .chUZKA{margin:0 !important;box-shadow:inset 0px -1px 0px #f8f8f9;border:none;height:1px;}/*!sc*/
# .bdgoVL{margin:0 !important;box-shadow:inset 0px -1px 0px #edeff0;border:none;height:1px;}/*!sc*/
# data-styled.g180[id="sc-dbXBFb"]{content:"chUZKA,bdgoVL,"}/*!sc*/
# .cyZDwx{margin-bottom:2px;}/*!sc*/
# .cwcWgf{margin-top:4px;}/*!sc*/
# .fQQqCd{margin-top:4px;margin-right:4px;}/*!sc*/
# .epIiaQ{margin-top:12px;}/*!sc*/
# .jiPlGx{margin-top:12px;margin-bottom:8px;}/*!sc*/
# data-styled.g228[id="sc-hxyAyv"]{content:"cyZDwx,cMiApS,cwcWgf,fQQqCd,epIiaQ,jiPlGx,"}/*!sc*/
# .ARwUf:hover{color:inherit;}/*!sc*/
# data-styled.g230[id="sc-hcmsuR"]{content:"ARwUf,"}/*!sc*/
# .eHXUSl:hover{color:inherit;}/*!sc*/
# data-styled.g231[id="sc-ojhmt"]{content:"eHXUSl,"}/*!sc*/
# .Wogov{display:block;position:relative;overflow:hidden;font-size:0;}/*!sc*/
# .hzfPgn{display:block;position:relative;overflow:hidden;font-size:0;padding-top:75%;background:#eee;}/*!sc*/
# data-styled.g237[id="sc-cfAQHH"]{content:"Wogov,hzfPgn,"}/*!sc*/
# .iPZlPc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:32px;}/*!sc*/
# @media (max-width:1023px){.iPZlPc{margin-right:8px;}}/*!sc*/
# data-styled.g332[id="Logo__Container-sc-1ctz71w-0"]{content:"iPZlPc,"}/*!sc*/
# .eXqjmq{width:110px;}/*!sc*/
# @media (max-width:1023px){.eXqjmq{width:80px;}}/*!sc*/
# .dDiewZ{width:110px;}/*!sc*/
# data-styled.g333[id="Logo__MainLogoSvg-sc-1ctz71w-1"]{content:"eXqjmq,dDiewZ,"}/*!sc*/
# .byGJWw{display:inline-block;white-space:nowrap;position:relative;color:inherit;}/*!sc*/
# .byGJWw::after{content:'';position:absolute;bottom:0px;left:0px;width:100%;height:3px;background-color:#1b1c1d;z-index:999;}/*!sc*/
# .byGJWw::after{display:none;}/*!sc*/
# @media (max-width:1023px){.byGJWw{padding:16px 0 10px;}}/*!sc*/
# @media (min-width:1024px){.byGJWw{padding:14px 0 12px;height:50px;}}/*!sc*/
# data-styled.g334[id="NavigationTab__Text-sc-1sw30ay-0"]{content:"byGJWw,"}/*!sc*/
# .fKOHkt{font-size:16px;font-weight:normal;color:#1b1c1d;line-height:24px;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;margin:0;position:relative;color:#1b1c1d;}/*!sc*/
# .fKOHkt:hover{color:inherit;font-weight:bold;}/*!sc*/
# @media (max-width:1023px){.fKOHkt{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;font-weight:initial;margin-right:20px;white-space:nowrap;color:#1b1c1d;}.fKOHkt:last-of-type{padding-right:16px;}}/*!sc*/
# @media (min-width:768px){.fKOHkt{width:auto;margin:0 24px;}}/*!sc*/
# @media (min-width:1024px){.fKOHkt{margin:0 28px;}}/*!sc*/
# data-styled.g335[id="NavigationTab__Tab-sc-1sw30ay-1"]{content:"fKOHkt,"}/*!sc*/
# .yQjXy{font-size:16px;font-weight:normal;color:#1b1c1d;line-height:24px;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;margin:0;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:14px 12px 12px 0;margin-right:16px;cursor:pointer;color:#1b1c1d;}/*!sc*/
# @media (max-width:1023px){.yQjXy{display:none;}}/*!sc*/
# data-styled.g338[id="MoreCategoryTab__Container-hpfiuo-1"]{content:"yQjXy,"}/*!sc*/
# .hmEBCe{position:relative;width:100%;background-color:#FFF;box-shadow:inset 0px -1px 0px #f8f8f9;}/*!sc*/
# @media (max-width:1023px){.hmEBCe{position:-webkit-sticky;position:sticky;top:0;z-index:999;box-shadow:inset 0 -1px #edeff0;}}/*!sc*/
# data-styled.g339[id="LandingCategoryNavigationBar__Container-sc-1ylmbl5-0"]{content:"hmEBCe,"}/*!sc*/
# .iqeqyz{width:100%;max-width:1176px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0 auto;box-shadow:inset 0px -1px 0px #f8f8f9;background-color:#FFF;}/*!sc*/
# @media (max-width:1239px){.iqeqyz{margin:0;padding:0 32px;}}/*!sc*/
# @media (max-width:1023px){.iqeqyz{padding:0 16px;overflow:auto;}.iqeqyz::-webkit-scrollbar{width:0;height:0;}}/*!sc*/
# @media (min-width:768px){.iqeqyz{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# data-styled.g340[id="LandingCategoryNavigationBar__NavigationBar-sc-1ylmbl5-1"]{content:"iqeqyz,"}/*!sc*/
# .iYlZQf{position:relative;}/*!sc*/
# data-styled.g361[id="OutSideNavigationCarousel__Content-sc-16l0zjo-0"]{content:"iYlZQf,"}/*!sc*/
# .eKiLDK{position:absolute;z-index:2;width:40px;height:40px;left:0;top:calc((100% - 0px) / 2);-webkit-transform:translateY(-50%) translateX(-52px);-ms-transform:translateY(-50%) translateX(-52px);transform:translateY(-50%) translateX(-52px);}/*!sc*/
# .eKiLDK:hover{background-color:#f8f8f9;}/*!sc*/
# .eKiLDK.disabled path{fill:#edeff0;}/*!sc*/
# @media (max-width:1023px){.eKiLDK{display:none;}}/*!sc*/
# @media (max-width:1239px){.eKiLDK{display:none;}}/*!sc*/
# data-styled.g362[id="OutSideNavigationCarousel__PrevButton-sc-16l0zjo-1"]{content:"eKiLDK,"}/*!sc*/
# .edUlBp{position:absolute;z-index:2;width:40px;height:40px;right:0;top:calc((100% - 0px) / 2);-webkit-transform:translateY(-50%) translateX(52px);-ms-transform:translateY(-50%) translateX(52px);transform:translateY(-50%) translateX(52px);}/*!sc*/
# .edUlBp:hover{background-color:#f8f8f9;}/*!sc*/
# .edUlBp.disabled path{fill:#edeff0;}/*!sc*/
# @media (max-width:1023px){.edUlBp{display:none;}}/*!sc*/
# @media (max-width:1239px){.edUlBp{display:none;}}/*!sc*/
# data-styled.g363[id="OutSideNavigationCarousel__NextButton-sc-16l0zjo-2"]{content:"edUlBp,"}/*!sc*/
# .isjcgA .swiper-slide{width:16.666666666666668%;}/*!sc*/
# @media (max-width:1023px){.isjcgA .swiper-slide{width:50%;}}/*!sc*/
# .isjcgA .swiper-pagination{display:none !important;}/*!sc*/
# .isjcgA .swiper-button-prev,.isjcgA .swiper-button-next{display:none !important;}/*!sc*/
# .isjcgA .swiper-pagination{bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .isjcgA .swiper-pagination-bullet{width:6px;height:6px;margin:0 8px;border-radius:3px;background-color:#FFF;opacity:0.56;}/*!sc*/
# .isjcgA .swiper-pagination-bullet-active{width:24px;background-color:#FFF;opacity:1;}/*!sc*/
# @media (max-width:1023px){.isjcgA.swiper-container{padding:0 24px;}}/*!sc*/
# data-styled.g364[id="OutSideNavigationCarousel__StyledSwiper-sc-16l0zjo-3"]{content:"isjcgA,"}/*!sc*/
# .gcsIPJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# @media (max-width:1023px){.gcsIPJ{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}}/*!sc*/
# data-styled.g372[id="AuthSkeleton__Container-sc-14x9ztl-0"]{content:"gcsIPJ,"}/*!sc*/
# .ekqIUN{height:40px;width:100%;border:0;-webkit-flex:1;-ms-flex:1;flex:1;padding-left:16px;padding-right:44px;font-size:14px;color:#1b1c1d;border-radius:3px;background-color:#FFF;box-shadow:0 0 1px 0 rgba(0,0,0,0.04),0 1px 3px 0 rgba(41,42,43,0.16);}/*!sc*/
# .ekqIUN > svg path{fill:#dde0e2;}/*!sc*/
# .ekqIUN::-webkit-input-placeholder{color:#3e4042;}/*!sc*/
# .ekqIUN::-moz-placeholder{color:#3e4042;}/*!sc*/
# .ekqIUN:-ms-input-placeholder{color:#3e4042;}/*!sc*/
# .ekqIUN::placeholder{color:#3e4042;}/*!sc*/
# .ekqIUN:hover{border:none;}/*!sc*/
# .ekqIUN:focus{background-color:#f8f8f9;border-radius:0 3px 0 0;box-shadow:0 0 1px 0 rgba(0,0,0,0.06),-0.5px 0 0 0 rgba(0,0,0,0.03);}/*!sc*/
# data-styled.g433[id="SearchInputBox__SearchBox-jbbx5m-0"]{content:"ekqIUN,"}/*!sc*/
# .YHJfi{position:absolute;top:0;right:0;width:44px;height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# data-styled.g434[id="SearchInputBox__IconWrapper-jbbx5m-1"]{content:"YHJfi,"}/*!sc*/
# .lamsiI{width:20px;height:20px;}/*!sc*/
# @media (max-width:1023px){.lamsiI{width:14px;height:14px;}}/*!sc*/
# data-styled.g435[id="SearchInputBox__SearchIcon-jbbx5m-2"]{content:"lamsiI,"}/*!sc*/
# .btmIOv{position:relative;z-index:1901;width:100%;height:40px;background-color:#FFF;}/*!sc*/
# data-styled.g436[id="SearchInputBox__Container-jbbx5m-3"]{content:"btmIOv,"}/*!sc*/
# .jNGAbG{position:fixed;top:0px;bottom:0px;left:0px;right:0px;opacity:0;z-index:1900;display:none;}/*!sc*/
# data-styled.g437[id="SearchInputBox__Background-jbbx5m-4"]{content:"jNGAbG,"}/*!sc*/
# .uQcK{position:relative;}/*!sc*/
# @media (min-width:1116px){.uQcK{width:100%;-webkit-transition:0.6s cubic-bezier(0.42,0,0.2,1);transition:0.6s cubic-bezier(0.42,0,0.2,1);}.uQcK:focus-within{width:420px;-webkit-transition:0.4s cubic-bezier(0.42,0,0.2,1);transition:0.4s cubic-bezier(0.42,0,0.2,1);}}/*!sc*/
# @media (max-width:1023px){.uQcK{position:static;}}/*!sc*/
# data-styled.g438[id="ProductKeywordListViewController__Container-sc-1gn3jvs-0"]{content:"uQcK,"}/*!sc*/
# .lpnxqi{background-color:white;box-shadow:none;}/*!sc*/
# data-styled.g442[id="MainHeader__HeaderWrapper-sc-4sw7cl-0"]{content:"lpnxqi,"}/*!sc*/
# .hgKCoP{margin-left:24px;margin-right:24px;padding:14px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;position:relative;}/*!sc*/
# @media (min-width:1024px) and (max-width:1239px){.hgKCoP{margin-left:32px;margin-right:32px;}}/*!sc*/
# @media (min-width:1240px){.hgKCoP{max-width:1176px;width:100%;margin-left:auto;margin-right:auto;}}/*!sc*/
# @media (max-width:1023px){.hgKCoP{padding:8px 0px 8px 16px;margin-left:0px;margin-right:16px;}}/*!sc*/
# data-styled.g443[id="MainHeader__UtilContainer-sc-4sw7cl-1"]{content:"hgKCoP,"}/*!sc*/
# .QyNWz{width:100%;max-width:380px;}/*!sc*/
# @media (max-width:1023px){.QyNWz{max-width:100%;margin:0 12px 0 8px;}}/*!sc*/
# data-styled.g444[id="MainHeader__SearchBoxWrapper-sc-4sw7cl-2"]{content:"QyNWz,"}/*!sc*/
# .kbRxzu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g445[id="MainHeader__LogoWrapper-sc-4sw7cl-3"]{content:"kbRxzu,"}/*!sc*/
# @media (max-width:1023px){.evsjYr{margin:0 -24px;}}/*!sc*/
# data-styled.g464[id="layouts__MobileScreenFitContainer-sc-1ufed85-1"]{content:"evsjYr,"}/*!sc*/
# .dAbiYG{margin-top:32px;}/*!sc*/
# @media (max-width:1023px){.dAbiYG{margin-top:24px;}}/*!sc*/
# data-styled.g484[id="InfiniteScrollGridList__LoaderGridList-sc-78h34u-0"]{content:"dAbiYG,"}/*!sc*/
# .eSsjHf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g558[id="style__Row-sc-1fua60n-0"]{content:"eSsjHf,"}/*!sc*/
# .khKJJa{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.khKJJa{margin-top:56px;padding:0 12px;}}/*!sc*/
# data-styled.g559[id="style__FirstMenuContainer-sc-1fua60n-1"]{content:"khKJJa,"}/*!sc*/
# .fAhJoN{display:none;margin-top:20px;margin-left:12px;margin-right:12px;height:1px;background-color:#edeff0;}/*!sc*/
# @media (max-width:1023px){.fAhJoN{display:block;}}/*!sc*/
# data-styled.g560[id="style__Line-sc-1fua60n-2"]{content:"fAhJoN,"}/*!sc*/
# .eYYlE{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.eYYlE{padding:0 12px;}}/*!sc*/
# data-styled.g561[id="style__SecondRow-sc-1fua60n-3"]{content:"eYYlE,"}/*!sc*/
# .fSyiAs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.fSyiAs{margin-top:0;border-top:1px solid #f8f8f9;padding-top:16px;}}/*!sc*/
# data-styled.g562[id="style__SecondRowFirstMenuContainer-sc-1fua60n-4"]{content:"fSyiAs,"}/*!sc*/
# .gSDLDD{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.gSDLDD{margin-top:16px;padding-top:16px;border-top:1px solid #f8f8f9;}}/*!sc*/
# data-styled.g563[id="style__SecondRowSecondMenuContainer-sc-1fua60n-5"]{content:"gSDLDD,"}/*!sc*/
# .fsIMct{font-style:normal;font-weight:normal;font-size:14px;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;color:#616568;font-feature-settings:'case' on,'ss02' on;margin-top:20px;}/*!sc*/
# data-styled.g564[id="style__Description-sc-1fua60n-6"]{content:"fsIMct,"}/*!sc*/
# .iflNUy{color:#1b1c1d;padding:8px 0;margin-top:12px;display:inline-block;cursor:pointer;}/*!sc*/
# data-styled.g566[id="style__GlobalDescription-sc-1fua60n-8"]{content:"iflNUy,"}/*!sc*/
# .hGsdji{color:#1b1c1d;margin-bottom:8px;padding-left:12px;font-size:16px;line-height:24px;}/*!sc*/
# data-styled.g567[id="style__Title-sc-1fua60n-9"]{content:"hGsdji,"}/*!sc*/
# .bJsGTl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g568[id="style__ExternalLink-sc-1fua60n-10"]{content:"bJsGTl,"}/*!sc*/
# .bhVAlz{color:#1b1c1d;-webkit-flex:1;-ms-flex:1;flex:1;padding:8px 12px;}/*!sc*/
# data-styled.g569[id="style__LinkTitle-sc-1fua60n-11"]{content:"bhVAlz,"}/*!sc*/
# .bBQPnO{margin-top:12px;display:none;color:#858a8d;text-align:center;}/*!sc*/
# @media (min-width:1024px){.bBQPnO{display:block;}}/*!sc*/
# data-styled.g570[id="style__CSDescription-sc-1fua60n-12"]{content:"bBQPnO,"}/*!sc*/
# .fuHZBo{border-radius:3px;font-style:normal;font-weight:bold;font-size:14px;line-height:20px;text-align:center;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;font-feature-settings:'case' on,'ss02' on;padding:0;box-sizing:border-box;width:100%;height:40px;color:#1b1c1d;}/*!sc*/
# @media (max-width:1023px){.fuHZBo:hover{background-color:#f8f8f9;}}/*!sc*/
# data-styled.g571[id="style__CSButton-sc-1fua60n-13"]{content:"fuHZBo,"}/*!sc*/
# .jCYZsC{display:block;float:right;margin:0;padding-right:12px;line-height:24px;color:#858a8d;}/*!sc*/
# @media (min-width:1024px){.jCYZsC{display:none;}}/*!sc*/
# data-styled.g572[id="style__CSDescriptionMobile-sc-1fua60n-14"]{content:"jCYZsC,"}/*!sc*/
# .fCCkwO{margin-left:12px;}/*!sc*/
# @media (max-width:1023px){.fCCkwO{margin-right:12px;}}/*!sc*/
# data-styled.g573[id="style__CSContainer-sc-1fua60n-15"]{content:"fCCkwO,"}/*!sc*/
# .kSJFHp{clear:both;}/*!sc*/
# data-styled.g574[id="style__TitleContainer-sc-1fua60n-16"]{content:"kSJFHp,"}/*!sc*/
# .gpBluL{float:left;}/*!sc*/
# data-styled.g575[id="style__CSTitle-sc-1fua60n-17"]{content:"gpBluL,"}/*!sc*/
# .gmBHMA{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;overflow:hidden;}/*!sc*/
# data-styled.g576[id="style__SmallLinkContainer-sc-1fua60n-18"]{content:"gmBHMA,"}/*!sc*/
# .dbAa-Dw{margin-left:-24px;}/*!sc*/
# data-styled.g577[id="style__SmallLinkInner-sc-1fua60n-19"]{content:"dbAa-Dw,"}/*!sc*/
# .cMohUM{font-style:normal;font-weight:normal;font-size:11px;line-height:16px;font-feature-settings:'case' on,'ss02' on;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;color:#858a8d;}/*!sc*/
# .cMohUM:before{display:block;width:24px;text-align:center;content:'･';}/*!sc*/
# .cMohUM:hover{color:'inherit';-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g578[id="style__SmallLink-sc-1fua60n-20"]{content:"cMohUM,"}/*!sc*/
# .ejMZtG{font-style:normal;font-weight:normal;font-size:9px;line-height:12px;font-feature-settings:'case' on,'ss02' on;color:#a8aeb3;margin-top:16px;}/*!sc*/
# data-styled.g579[id="style__IncDescription-sc-1fua60n-21"]{content:"ejMZtG,"}/*!sc*/
# .gxxlTD{position:relative;}/*!sc*/
# @media (max-width:1023px){.gxxlTD{padding:0 12px;}}/*!sc*/
# data-styled.g580[id="style__FooterContainer-sc-1fua60n-22"]{content:"gxxlTD,"}/*!sc*/
# .iEHxuM{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;width:100%;margin-top:24px;}/*!sc*/
# data-styled.g581[id="style__MenuContainer-sc-1fua60n-23"]{content:"iEHxuM,"}/*!sc*/
# .qtAzl{margin-top:16px;font-weight:bold;}/*!sc*/
# @media (max-width:1023px){.qtAzl:hover{background-color:#f8f8f9;}}/*!sc*/
# data-styled.g582[id="style__AppDownloadButton-sc-1fua60n-24"]{content:"qtAzl,"}/*!sc*/
# .hJibbv{border-top:1px solid #edeff0;background-color:#FFF;padding-bottom:32px;}/*!sc*/
# @media (min-width:1024px){.hJibbv{padding-top:40px;padding-bottom:64px;}}/*!sc*/
# @media (max-width:1023px){.hJibbv{padding-bottom:72px;}}/*!sc*/
# ...
#            크리에이터 지원하기
#           </div>
#          </a>
#          <a class="style__ExternalLink-sc-1fua60n-10 bJsGTl" href="https://creator.class101.net/creator/help" rel="noreferrer" target="_blank">
#           <div class="sc-bdnylx bQhOjs style__LinkTitle-sc-1fua60n-11 bhVAlz">
#            도움말
#           </div>
#          </a>
#         </div>
#         <div class="style__MenuContainer-sc-1fua60n-23 iEHxuM">
#          <div class="style__TitleContainer-sc-1fua60n-16 kSJFHp">
#           <div class="sc-bdnylx biNtgO style__Title-sc-1fua60n-9 style__CSTitle-sc-1fua60n-17 hGsdji gpBluL" font-weight="bold">
#            고객센터
#           </div>
#           <div class="sc-bdnylx joKiRU style__CSDescriptionMobile-sc-1fua60n-14 jCYZsC">
#            오전 10시 ~ 오후 6시 (주말, 공휴일 제외)
#           </div>
#          </div>
#          <div class="style__CSContainer-sc-1fua60n-15 fCCkwO">
#           <button class="sc-ksluoS dyNqkJ sc-kfYqjs dEOcBP style__CSButton-sc-1fua60n-13 fuHZBo" color="default" fill="true" type="button">
#            <span class="sc-hBMVcZ liuvoF">
#             문의하기
#            </span>
#           </button>
#           <div class="sc-bdnylx bQhOjs style__CSDescription-sc-1fua60n-12 bBQPnO">
#            오전 10시 ~ 오후 6시 (주말, 공휴일 제외)
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="style__Row-sc-1fua60n-0 style__SecondRow-sc-1fua60n-3 eSsjHf eYYlE">
#         <div class="style__SecondRowFirstMenuContainer-sc-1fua60n-4 fSyiAs">
#          <div class="style__SmallLinkContainer-sc-1fua60n-18 gmBHMA">
#           <div class="style__SmallLinkInner-sc-1fua60n-19 dbAa-Dw">
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.net/" rel="noreferrer" target="_blank">
#             CLASS101 Korea
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://en.class101.net/" rel="noreferrer" target="_blank">
#             CLASS101 USA
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.jp/" rel="noreferrer" target="_blank">
#             CLASS101 Japan
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://www.instagram.com/class101_official/" rel="noreferrer" target="_blank">
#             Instagram
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://www.youtube.com/channel/UCDJ1ZXSnt37KLaLFPFlBkqw" rel="noreferrer" target="_blank">
#             Youtube
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://www.facebook.com/Class101Korea/" rel="noreferrer" target="_blank">
#             Facebook
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://post.naver.com/class101_official" rel="noreferrer" target="_blank">
#             Naverpost
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://blog.naver.com/class101_official" rel="noreferrer" target="_blank">
#             Naverblog
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.app/fd" rel="noreferrer" target="_blank">
#             Playstore
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.app/fd" rel="noreferrer" target="_blank">
#             Appstore
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="style__SecondRowSecondMenuContainer-sc-1fua60n-5 gSDLDD">
#          <div class="style__SmallLinkContainer-sc-1fua60n-18 gmBHMA">
#           <div class="style__SmallLinkInner-sc-1fua60n-19 dbAa-Dw">
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.net/docs/terms" rel="noreferrer" target="_blank">
#             이용약관
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.net/docs/privacy" rel="noreferrer" target="_blank">
#             <b>
#              개인정보 처리방침
#             </b>
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.net/docs/refund" rel="noreferrer" target="_blank">
#             환불 정책
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=4578100277" rel="noreferrer" target="_blank">
#             사업자 정보 확인
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="mailto: with@101.inc" rel="noreferrer" target="_blank">
#             제휴/협력 문의
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://class101.net/events/5f505aff730fe20013afbbc4" rel="noreferrer" target="_blank">
#             단체/기업 교육 문의
#            </a>
#            <a class="style__SmallLink-sc-1fua60n-20 cMohUM" href="https://docs.google.com/document/d/1lHDVXIGhUORLxy3LVS8dQv_G27nn7AqX32LafoeCCkA" rel="noreferrer" target="_blank">
#             정기구독서비스 이용약관
#            </a>
#           </div>
#          </div>
#          <div class="style__IncDescription-sc-1fua60n-21 ejMZtG">
#           (주)클래스101 | 대표 고지연 | 서울특별시 중구 통일로 10 세브란스빌딩 18층 | 사업자등록번호 : 457-81-00277 | 통신판매업신고 : 2019-서울중구-0087 | 주식회사 클래스101은 전자상거래 등에서의 소비자보호에 관한 법률에 따른 통신판매업과 통신판매중개업을 영위하고 있습니다. 주식회사 클래스101은 통신판매중개자로서 중개하는 통신판매에 관하여서는 통신판매의 당사자가 아니므로 어떠한 책임도 부담하지 아니합니다.
#          </div>
#         </div>
#        </div>
#        <span class="sc-fnVYJo aqTZb sc-kfYqjs dEOcBP style__AppDownloadButton-sc-1fua60n-24 qtAzl">
#         <a class="sc-hcmsuR ARwUf sc-dlnjPT sc-fFSRdu cuIYFB goHICw" color="default" fill="true" href="https://class101.app/fd" rel="noreferrer" target="_blank">
#          <div class="sc-bqGHjH fJNMMN">
#           <svg height="18" viewbox="0 0 24 24" width="18">
#            <path d="M4.033 21.26A1.016 1.016 0 014 21V3c0-.09.012-.178.033-.26l9.26 9.26-9.26 9.26zm.708.706L14 12.707l2.802 2.802L5.49 21.872a.986.986 0 01-.75.094zM16.8 8.491L14 11.293l-9.26-9.26a.986.986 0 01.75.095l11.312 6.363zm.906.51l3.783 2.127a1 1 0 010 1.744L17.707 15l-3-3 3-3z" fill="#1b1c1d" fill-rule="evenodd">
#            </path>
#           </svg>
#          </div>
#          <span class="sc-hBMVcZ liuvoF">
#           앱 다운로드
#          </span>
#         </a>
#        </span>
#       </div>
#      </footer>
#     </div>
#     <div class="LegacyModals__ModalWrapper-sc-83r6dn-0 kyxOSF">
#     </div>
#    </div>
#   </div>
#   <script>
#    window.__APOLLO_STATE__ = {"ProductWorkStory:5ff2beaad71f406511dde2a4":{"_id":"5ff2beaad71f406511dde2a4","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/82a920df-cfcd-4480-9ac2-fbfdca31ae39","mediaOriginalFileName":"stretchjoy_120052144_200934608115518_8073534190088101705_n.jpg","content":"요가, 필라테스, 헬스, 등 운동을 할 때 몸이 마음대로 움직이지 않아 답답하셨나요? 어깨, 목, 허리, 통증을 달고 사신다고요? "},"ProductWorkStory:5ff2beaad71f406511dde2a5":{"_id":"5ff2beaad71f406511dde2a5","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/725dcc48-d738-49cb-b05e-9f051bff076e","mediaOriginalFileName":"stretchjoy_60983911_187307075597245_6152766165577006849_n.jpg","content":"이제는 선택이 아닌 필수! 내 몸을 늘려주는 스트레칭이 필요합니다. 굳은 몸을 스트레칭으로 풀어주기만 해도 부종이 빠지고, 통증에도 도움이 됩니다."},"ProductWorkStory:5ff2beaad71f406511dde2a6":{"_id":"5ff2beaad71f406511dde2a6","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/d443ffc9-4c8e-4b4d-a025-05c85495ee98","mediaOriginalFileName":"stretchjoy_52011469_332273620728222_6953547896031727664_n.jpg","content":"나혼○ 산다에 나왔던 바로 그 스트레칭! 43cm에서 32cm로 나올 수 있었던 바로 그 비법! 모두 공개합니다. "},"ProductWorkStory:5ff2beaad71f406511dde2a7":{"_id":"5ff2beaad71f406511dde2a7","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/8134dfce-6a77-4aa4-90d4-b4de31ffd814","mediaOriginalFileName":"스크린샷 2020-11-30 오후 10.00.05.png","content":"지금까지 단순하게 생각했던 스트레칭과는 전혀 다른 '스트레칭 운동'을 만나실 수 있게 도와드릴게요.   "},"ProductWorkStory:5ff2beaad71f406511dde2a8":{"_id":"5ff2beaad71f406511dde2a8","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/c58a849b-798a-4756-9783-9847f8ecd598","mediaOriginalFileName":"그림1.png","content":"[다리 찢기]\n누구나 가능합니다. 여러분의 숨겨진 가동성을 강제적이 아닌, 몸에 맞게 늘려주는 훈련을 함께 해요."},"ProductWorkStory:5ff2beaad71f406511dde2a9":{"_id":"5ff2beaad71f406511dde2a9","__typename":"ProductWorkStory","mediaType":"Video","mediaUrl":"91b7474c-0409-4f96-a085-d6ba59437b66","mediaOriginalFileName":"stretchjoy_61174440_416203208935643_1201660008228921049_n.mp4","content":"근막이완부터, 초급, 중급, 고급까지! 하루 20분 스트레칭 프로그램으로 뻣뻣했던 여러분의 다리가 앞으로 그리고 옆으로 늘어날수 있게 도와드릴게요."},"ProductWorkStory:5ff2beaad71f406511dde2aa":{"_id":"5ff2beaad71f406511dde2aa","__typename":"ProductWorkStory","mediaType":"Video","mediaUrl":"0b7747f6-68a2-45c7-b567-0d8055f0a304","mediaOriginalFileName":"stretchjoy_87984671_106627094165070_2720674755316912007_n (1).mp4","content":"[전신 스트레칭]\n어깨, 목, 허리, 골반, 엉덩이,그리고 종아리까지 부위별로 딱딱하게 굳어있는 근육들을 자극해 몸이 바르게 서게 도와줍니다."},"ProductWorkStory:5ff2beaad71f406511dde2ab":{"_id":"5ff2beaad71f406511dde2ab","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/d35bc926-62cd-4075-be8b-e48aece11bca","mediaOriginalFileName":"스크린샷 2020-11-30 오후 11.09.40.png","content":"자신에게 꼭 필요한 스트레칭을 꾸준히 따라 하면 혈액순환이 좋아지며, 몸과 라인이 살아나고, 신체 능력이 향상될 거예요.  "},"ProductWorkStory:5ff2beaad71f406511dde2ac":{"_id":"5ff2beaad71f406511dde2ac","__typename":"ProductWorkStory","mediaType":"Image","mediaUrl":"https://cdn.class101.net/images/993e2d46-fac5-404e-bd11-96182b6a25d2","mediaOriginalFileName":"stretchjoy_53515226_263032081243066_9013540341178667102_n.jpg","content":"스트레칭 조이와 함께 쓸모있는 몸을 만들어봐요!"},"Category:5ea2b372fdaf6841ea893f6a":{"_id":"5ea2b372fdaf6841ea893f6a","__typename":"Category","title":"운동"},"User:5fa913cf18a5eb001313fa05":{"_id":"5fa913cf18a5eb001313fa05","__typename":"User","firestoreId":"kakao1526955777","name":"김성종","nickName":"스트레칭조이 ","photoUrl":"https://cdn.class101.net/images/aae7787f-12fc-487d-a97e-f7a6fdb79484","channels":[{"__typename":"Channel","type":"Instagram","url":"https://www.instagram.com/stretchjoy","channelId":"stretchjoy"},{"__typename":"Channel","type":"Youtube","url":"https://www.youtube.com/channel/UC7jfcWMKdtypYEPPtpRboow?sub_confirmation=1","channelId":"스트레칭조이"},{"__typename":"Channel","type":"기타","url":"https://stretchjoy.modoo.at/?NaPm=ct%3Dki3 ...
#   </script>
#   <script>
#    if (typeof window.__REACT_DEVTOOLS_GLOBAL_HOOK__ === 'object') {
#                  __REACT_DEVTOOLS_GLOBAL_HOOK__.inject = function() {};
#               }
#   </script>
#   <script crossorigin="true" src="/static/js/client.5dec2ca3.chunk.js">
#   </script>
#   <script crossorigin="true" id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [79,0,1,2,7,46]
#   </script>
#   <script crossorigin="true" id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">
#    {"namedChunks":["i18n-ko-json","MainPageHeroBanner","CreativePage"]}
#   </script>
#   <script async="" crossorigin="true" data-chunk="client" src="/static/js/runtime~client.99bc65b3.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="client" src="/static/js/vendors.5a596ec9.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="client" src="/static/js/vendors~client.10d2a1fd.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="client" src="/static/js/client.5dec2ca3.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="MainPageHeroBanner" src="/static/js/MainPageHeroBanner.02101a02.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="CreativePage" src="/static/js/BusinessSearchPage~CareerPage~CategoryDetailPage~CollectionDetailPage~CommonLandingPage~CouponNotice~623c25af.4a70763b.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="CreativePage" src="/static/js/BusinessPage~BusinessSearchPage~CareerPage~CategoryDetailPage~CollectionDetailPage~CouponNoticePage~~0da93547.477a0f6f.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="CreativePage" src="/static/js/BusinessSearchPage~CareerPage~CategoryDetailPage~CollectionDetailPage~CouponNoticePage~CreativePage~~964737e5.9da48104.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="CreativePage" src="/static/js/CareerPage~CollectionDetailPage~CreativePage~EarlybirdPage~MoneyPage~NewUserLandingPage~RewardCheerU~4119b7b0.7e73443f.chunk.js">
#   </script>
#   <script async="" crossorigin="true" data-chunk="CreativePage" src="/static/js/CreativePage.e2cd789b.chunk.js">
#   </script>
#   <div id="portal">
#   </div>
#   <div id="global-portal-area">
#   </div>
#   <div id="ch-plugin">
#   </div>
#   <script src="/vendor/naverlogin.min.js" type="text/javascript">
#   </script>
#   <script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript">
#   </script>
#   <script async="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Kakao.init('bb2203fc061b5da4a9e1152da81610e1');
#   </script>
#   <script type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "name": "Class101",
#     "email": "mailto:ask@class101.net",
#     "url": "https://class101.net",
#     "sameAs": [
#       "https://www.instagram.com/class101_official",
#       "https://twitter.com/Class101Korea",
#       "https://www.facebook.com/Class101Korea/",
#       "https://itunes.apple.com/kr/app/class101-클래스101/id1320607634",
#       "https://play.google.com/store/apps/details?id=net.pedaling.class101",
#       "https://tv.naver.com/class101",
#       "https://pf.kakao.com/_xcxmxgcxl",
#       "https://www.youtube.com/channel/UCDJ1ZXSnt37KLaLFPFlBkqw"
#     ]
#   }
#   </script>
#   <script>
#    window.channelPluginSettings = {
#     pluginKey: '4b19a129-f419-450e-8b38-3d0339f895eb',
#     zIndex: 1000,
#   };
#   (function () {
#     var w = window;
#     if (w.ChannelIO) {
#       return (window.console.error || window.console.log || function () {})('ChannelIO script included twice.');
#     }
#     var d = window.document;
#     var ch = function () {
#       ch.c(arguments);
#     };
#     ch.q = [];
#     ch.c = function (args) {
#       ch.q.push(args);
#     };
#     w.ChannelIO = ch;
#     function l() {
#       if (w.ChannelIOInitialized) {
#         return;
#       }
#       w.ChannelIOInitialized = true;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.src = 'https://cdn.channel.io/plugin/ch-plugin-web.js';
#       s.charset = 'UTF-8';
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#     }
#     if (document.readyState === 'complete') {
#       l();
#     } else if (window.attachEvent) {
#       window.attachEvent('onload', l);
#     } else {
#       window.addEventListener('DOMContentLoaded', l, false);
#       window.addEventListener('load', l, false);
#     }
#   })();
#   </script>
#   <script type="text/javascript">
#    (function () {
#     var w = window;
#     var ic = w.Intercom;
#     if (typeof ic === 'function') {
#         ic('reattach_activator');
#         ic('update', w.intercomSettings);
#     } else {
#         var d = document;
#         var i = function () {
#             i.c(arguments);
#         };
#         i.q = [];
#         i.c = function (args) {
#             i.q.push(args);
#         };
#         w.Intercom = i;
#         var l = function () {
#             var s = d.createElement('script');
#             s.type = 'text/javascript';
#             s.async = true;
#             s.src = 'https://widget.intercom.io/widget/' + 'unjfsjy5';
#             var x = d.getElementsByTagName('script')[0];
#             x.parentNode.insertBefore(s, x);
#         };
#         if (w.attachEvent) {
#             w.attachEvent('onload', l);
#         } else {
#             w.addEventListener('load', l, false);
#         }
#     }
#   })();
#   </script>
#   <script src="/vendor/outdated-browser.min.js" type="text/javascript">
#   </script>
#   <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
tab_links = soup.find_all('a', class_=["NavigationTab__Tab-sc-1sw30ay-1", "fKOHkt"])
tab_links
# Out:
# [<a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">전체</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/creative"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">크리에이티브</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/money"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">머니</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/career"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">커리어</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/kids"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">키즈</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/signature"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">시그니처</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/libre"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">리브레</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/store"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">스토어</span></a>,
#  <a class="NavigationTab__Tab-sc-1sw30ay-1 fKOHkt" href="/business/landing"><span class="NavigationTab__Text-sc-1sw30ay-0 byGJWw">For Business</span></a>]

# %%
tabs = []
for i in range(1, len(tab_links)-1):
    tabs.append(base+(tab_links[i].attrs['href']))
    
tabs
# Out:
# ['https://class101.net/creative',
#  'https://class101.net/money',
#  'https://class101.net/career',
#  'https://class101.net/kids',
#  'https://class101.net/signature',
#  'https://class101.net/libre',
#  'https://class101.net/store']

# %%
extra = tabs[6]

# %%
for j  in tabs:
    print(j)
    
ntabs = tabs[:4]

l = []

for i in ntabs:
    l.append(i)
l.append(extra)
# Out:
# https://class101.net/creative
# https://class101.net/money
# https://class101.net/career
# https://class101.net/kids
# https://class101.net/signature
# https://class101.net/libre
# https://class101.net/store

# %%
l
# Out:
# ['https://class101.net/creative',
#  'https://class101.net/money',
#  'https://class101.net/career',
#  'https://class101.net/kids',
#  'https://class101.net/store']

# %%
df = pd.DataFrame(l)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6f97eb7d9937> in <module>
# ----> 1 df = pd.DataFrame(l)
#       2 df
#
# NameError: name 'l' is not defined

# %%
df.to_csv("parent_links.csv")

# %% [markdown]
# # Product Link Extraction of 5

# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
base = "https://class101.net"

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

urls = pd.read_csv('parent_links.csv')
urls = urls.drop(['Unnamed: 0'], axis = 1) 
    
b = list(urls['0'])
b = b[:5]

a = []

for i in range(len(b)):
    url = b[i]
    print(url)
    
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')
    driver.get(url)
    time.sleep(3)    
    source_code = driver.page_source
    soup = BeautifulSoup(source_code, 'html.parser')

    # top 10
    iii = []
    bb = []
    outsidenav = soup.find_all("div", class_=['SectionWithOutSideNavigationCarousel__Content-laj44i-0', 'cTNIGb'])
    for do in outsidenav:
        d = do.find_all('div', class_ =["OutSideNavigationCarousel2__Content-lxp9vi-0","fhZyLW"])
        for i in d:
            ii = i.find_all('a', ["ProductCardfragment__HoverStyledLink-jvv2ql-0", "lmeJlb"])
            for ai in ii:
                bb.append(base+ai.attrs['href'])
                if url == "https://class101.net/creative":
                    bb.append(["Creative", base+ai.attrs['href']])
                elif url == "https://class101.net/money":
                    bb.append(["Money", base+ai.attrs['href']])
                elif url == "https://class101.net/career":
                    bb.append(["Career", base+ai.attrs['href']])
                elif url == "https://class101.net/kids":
                    bb.append(["Kids", base+ai.attrs['href']])
                else:
                    bb.append(["Signature", base+ai.attrs['href']])
                
    a.append(bb)
    driver.quit()
# Out:
# https://class101.net/creative
# https://class101.net/money
# https://class101.net/career
# https://class101.net/kids
# https://class101.net/signature

# %%
a
# Out:
# [['https://class101.net/products/MeWbxFNvpDjWA67CWylo',
#   'https://class101.net/products/taAqhVz62rYVn7JFZYY7',
#   'https://class101.net/products/YxoLEEDOqDUH3NZ1PBJ0',
#   'https://class101.net/products/6zymWqgESI5vlAS8XGVv',
#   'https://class101.net/products/eQ0bkTGij6wioYNSya88',
#   'https://class101.net/products/SuRY3jkWhHoOW4GHu6NQ',
#   'https://class101.net/products/TVGZnhMLoqiuvvOd0956',
#   'https://class101.net/products/aGWkyjGR9BeQnYVYSYPu',
#   'https://class101.net/products/hf3H7C5T96VByVsA3ZRz',
#   'https://class101.net/products/2XmAanyYa7IuDNqtPyve',
#   'https://class101.net/products/MeWbxFNvpDjWA67CWylo',
#   'https://class101.net/products/MsbVkx56JxutdRmnicny',
#   'https://class101.net/products/F6Xf6LKeOoHjLTCE3eld',
#   'https://class101.net/products/NrbBnnFXggAakHmMZp8y',
#   'https://class101.net/products/TVGZnhMLoqiuvvOd0956',
#   'https://class101.net/products/6zymWqgESI5vlAS8XGVv',
#   'https://class101.net/products/R38sGT9W1TuFuerrUoYy',
#   'https://class101.net/products/K3Zo8qnNlSMOm0zOPTI2',
#   'https://class101.net/products/49fhFO02i3bbSQkjZnXk',
#   'https://class101.net/products/jpJZhobyWAAp6m7x50gp',
#   'https://class101.net/products/waZdZ8YMllQDiHVX2HPI',
#   'https://class101.net/products/U8Vk8CInpQhHuHNm6JPI',
#   'https://class101.net/products/V9wKu8BSOFkgpDb6QQWb',
#   'https://class101.net/products/bGGMXq2f3Jyudq4ocUFD',
#   'https://class101.net/products/WtBaedR99dBNVxYHFRZ0',
#   'https://class101.net/products/apiV6fBr5laNbFU5NrWh',
#   'https://class101.net/products/eUr7fRGk7j2cIpYu03ul',
#   'https://class101.net/products/wefe0AyQCC27HhMjtpZK',
#   'https://class101.net/products/DfmjiR8ArmVQJbvr4uks',
#   'https://class101.net/products/oLKNfXQI1ZhPzVSIBYc1'],
#  ['https://class101.net/products/nE3Rka3C8quVUg6sJTXu',
#   'https://class101.net/products/zaswQi8tonzayH30fpDq',
#   'https://class101.net/products/kl0DdlkkXGyssJdqUHeK',
#   'https://class101.net/products/6JEEdjUieqshYeSb7ALy',
#   'https://class101.net/products/KPPdqrZv7ZQ6CrDU0VVa',
#   'https://class101.net/products/M7QbyoAue23dUEutSPtn',
#   'https://class101.net/products/j2cqasKulOEI8EtcgWmd',
#   'https://class101.net/products/AKwX4czUR18hIyk1A8gk',
#   'https://class101.net/products/Xl3FzgGJCzgid7nsKIjE',
#   'https://class101.net/products/fBcuqxuLShuEZXVFNfHV',
#   'https://class101.net/products/zaswQi8tonzayH30fpDq',
#   'https://class101.net/products/uEBzVly2IVJ2CEx4sDQr',
#   'https://class101.net/products/fBcuqxuLShuEZXVFNfHV',
#   'https://class101.net/products/5kc1EBRqWfhnsuV9evOx',
#   'https://class101.net/products/M7QbyoAue23dUEutSPtn',
#   'https://class101.net/products/3gKaNMDL5cbK5yrsjGjl',
#   'https://class101.net/products/euQLyhEAZaDB3APwPIhp',
#   'https://class101.net/products/c8seZ48pAQM8OE2kV3sO',
#   'https://class101.net/products/xLhiDKT5DfsMTqUIRIQj',
#   'https://class101.net/products/231Y9Tp87jdIGgeGWnmB',
#   'https://class101.net/products/Qh7sxfNGTISLviHlBxJs',
#   'https://class101.net/products/PSlpXWSHMShO7FdDd95C',
#   'https://class101.net/products/Y43DsSESpZQd3wUA9s16',
#   'https://class101.net/products/tyMQDrtQpP8M56H4Le5k',
#   'https://class101.net/products/j2cqasKulOEI8EtcgWmd',
#   'https://class101.net/products/yvivFBDvXqRYaZfawhdK',
#   'https://class101.net/products/A2GelVK2395umPzoEfeL',
#   'https://class101.net/products/PH5YxomvF2NSVkCxvJO2',
#   'https://class101.net/products/WX8jygr4SWiJEQ5ZnnDf',
#   'https://class101.net/products/KPPdqrZv7ZQ6CrDU0VVa'],
#  ['https://class101.net/products/vzITnUK9I5BC6J98OI06',
#   'https://class101.net/products/Nl3FICmR5yj9gDBY3JHt',
#   'https://class101.net/products/HqYy7CbUm1E7SdvvT1sh',
#   'https://class101.net/products/euWprzr7oOp0CpidXfEF',
#   'https://class101.net/products/tk9ZcndBfpAWMkcSuln9',
#   'https://class101.net/products/OWXndRN1fzytZU5fGAGN',
#   'https://class101.net/products/vfU6Ngy8gwmP2MA8vx06',
#   'https://class101.net/products/5RcUZlcjCDVulejewYvU',
#   'https://class101.net/products/UBNMsXOO8ZXMUXwRwDOu',
#   'https://class101.net/products/0khf0PHxnnbi5xHQc7G8',
#   'https://class101.net/products/oU5yNXIHjzpmyJsyeIMI',
#   'https://class101.net/products/b2oUFNRxQkb7ih5odCl4',
#   'https://class101.net/products/vfU6Ngy8gwmP2MA8vx06',
#   'https://class101.net/products/QDnu5PUZtAXYRivB7nyK',
#   'https://class101.net/products/YsNqf8So7bTGhglgLO88',
#   'https://class101.net/products/UBNMsXOO8ZXMUXwRwDOu',
#   'https://class101.net/products/s3Fce0m08mg5tbofkqtt',
#   'https://class101.net/products/0ofDird72EX7KEA2VxSu',
#   'https://class101.net/products/o1RR5S1rD3TFX4bnzZjz',
#   'https://class101.net/products/4rb9WsmLEP9s9aXtlwIo',
#   'https://class101.net/products/27XjxD8ButCvfZ1YuV1k',
#   'https://class101.net/products/kSa7H0nxsl63s7kXAT3D',
#   'https://class101.net/products/OWXndRN1fzytZU5fGAGN',
#   'https://class101.net/products/DiyaOKpLFulcHhiRncVt',
#   'https://class101.net/products/F6xgvoP9kluwjSvpHkV5',
#   'https://class101.net/products/oSXuVhROXZ94wmK6u78h',
#   'https://class101.net/products/13E4VQEJSwUhyRbIFQ6p',
#   'https://class101.net/products/GQDTG8Byxbv1DDSdWgpu',
#   'https://class101.net/products/3z9C8zuWUHUWcjUAHJNh',
#   'https://class101.net/products/tZU7EB5zjyEoyBg5uWCs'],
#  ['https://class101.net/products/TCFyXX6He5cWP3xLgiqc',
#   'https://class101.net/products/hWLdhNUo4rpxBeJ8zzOo',
#   'https://class101.net/products/yIUPwvqXcc0IaXH5RvW6',
#   'https://class101.net/products/OPsaXf3hHAavXtmzyVxK',
#   'https://class101.net/products/pAk9ijtO8nPWERlZghpy',
#   'https://class101.net/products/S5LzMTmdqZTgAlOd0ShN',
#   'https://class101.net/products/RJpO8VbR6VCSvVOJuxkf',
#   'https://class101.net/products/QWqBKncbHWid1oaNZQuB',
#   'https://class101.net/products/KH6ZsAFjVBIRLDryntuW',
#   'https://class101.net/products/gFp5RIfeeiAlo4tXOQz6',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/XPnvdRSAzYMYaJ8o0aGb',
#   'https://class101.net/products/y1Wm9IcpJb7UyP7CTz6D',
#   'https://class101.net/products/1YUtxPBHb7jwmPVGrdNq',
#   'https://class101.net/products/f6KtL54kNeGxfA9IDsK6',
#   'https://class101.net/products/5T4IxMiHokMgrNBSIV1T',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/hxehoorQf5xbxXK4MsOi',
#   'https://class101.net/products/LQ8QCbf39IgWXrWK24YO',
#   'https://class101.net/products/SuC7g4unbHX10YnjNiFP',
#   'https://class101.net/products/YsNqf8So7bTGhglgLO88',
#   'https://class101.net/products/su8p0H8QzsYOoZOrBSZI',
#   'https://class101.net/products/1N8gZXNv78SCex4ZY3xF',
#   'https://class101.net/products/tCKI0COJ6pFIvqxCJpMv',
#   'https://class101.net/products/RzNsjkAj39S5Rz2FlDDV',
#   'https://class101.net/products/iy5i270NDFNxiEd1OMDn',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/Otmgd0tIQJuPgVpitLhU',
#   'https://class101.net/products/QpX43F2QMPLZDbHOJU6L',
#   'https://class101.net/products/BOgzav5JOBuzKzagJmar',
#   'https://class101.net/products/5T4IxMiHokMgrNBSIV1T',
#   'https://class101.net/products/LQ8QCbf39IgWXrWK24YO',
#   'https://class101.net/products/XPnvdRSAzYMYaJ8o0aGb',
#   'https://class101.net/products/bFSTbFljZ3R1SOPaXK1l',
#   'https://class101.net/products/lqXzLSU0CjINUl0DDhSq',
#   'https://class101.net/products/BgLKl53Z5Gc3LOrzGnHj',
#   'https://class101.net/products/mZxyOTrCjLmdkGni10Hu',
#   'https://class101.net/products/ThmOyNOotc6CfKnkgAqa',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/Ha3AEzrtwl2RxXjjmpid',
#   'https://class101.net/products/f6KtL54kNeGxfA9IDsK6',
#   'https://class101.net/products/1YUtxPBHb7jwmPVGrdNq',
#   'https://class101.net/products/hxehoorQf5xbxXK4MsOi',
#   'https://class101.net/products/SuC7g4unbHX10YnjNiFP',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/Otmgd0tIQJuPgVpitLhU',
#   'https://class101.net/products/QpX43F2QMPLZDbHOJU6L',
#   'https://class101.net/products/LT0H8FAjCjICCpJvoADR',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/m88NZ3qdFzAg2hHDbkwy',
#   'https://class101.net/products/w7lAcHYx3RYuBCGykIoH',
#   'https://class101.net/products/2R71QlOwxRq83dmXhOnk',
#   'https://class101.net/products/kt0eQzZJKlIL4NESbdqd',
#   'https://class101.net/products/IsuucrmPvI03ujdnpEfB',
#   'https://class101.net/products/iEShQk7jm9UqC2AA2NGt',
#   'https://class101.net/products/1rQ7q3dNwnVCIqGtdAOn',
#   'https://class101.net/products/IV0CGre7RKTVCpJX3p0E',
#   'https://class101.net/products/FiPQcs8iwCYgMzfEnUwh',
#   'https://class101.net/products/qmNEx8kjiSG9ECZVKNy4',
#   'https://class101.net/products/9VvFv8hwkkPPcxK4GzuM',
#   'https://class101.net/products/y1Wm9IcpJb7UyP7CTz6D',
#   'https://class101.net/products/hgsRnnZ2DFgdHWsn7doq',
#   'https://class101.net/products/e8DBpMLGQRKStLCUpcWn',
#   'https://class101.net/products/2z6xfLAReIjpToK9mffq',
#   'https://class101.net/products/RLPQ6q1IBjylKDhnDYfT',
#   'https://class101.net/products/udOxzzIfjUPTLYQo23gq',
#   'https://class101.net/products/TCFyXX6He5cWP3xLgiqc',
#   'https://class101.net/products/hWLdhNUo4rpxBeJ8zzOo',
#   'https://class101.net/products/yIUPwvqXcc0IaXH5RvW6',
#   'https://class101.net/products/OPsaXf3hHAavXtmzyVxK',
#   'https://class101.net/products/pAk9ijtO8nPWERlZghpy',
#   'https://class101.net/products/S5LzMTmdqZTgAlOd0ShN',
#   'https://class101.net/products/KH6ZsAFjVBIRLDryntuW',
#   'https://class101.net/products/RJpO8VbR6VCSvVOJuxkf',
#   'https://class101.net/products/QWqBKncbHWid1oaNZQuB',
#   'https://class101.net/products/gFp5RIfeeiAlo4tXOQz6',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/XPnvdRSAzYMYaJ8o0aGb',
#   'https://class101.net/products/y1Wm9IcpJb7UyP7CTz6D',
#   'https://class101.net/products/1YUtxPBHb7jwmPVGrdNq',
#   'https://class101.net/products/f6KtL54kNeGxfA9IDsK6',
#   'https://class101.net/products/5T4IxMiHokMgrNBSIV1T',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/hxehoorQf5xbxXK4MsOi',
#   'https://class101.net/products/LQ8QCbf39IgWXrWK24YO',
#   'https://class101.net/products/SuC7g4unbHX10YnjNiFP',
#   'https://class101.net/products/YsNqf8So7bTGhglgLO88',
#   'https://class101.net/products/su8p0H8QzsYOoZOrBSZI',
#   'https://class101.net/products/1N8gZXNv78SCex4ZY3xF',
#   'https://class101.net/products/tCKI0COJ6pFIvqxCJpMv',
#   'https://class101.net/products/RzNsjkAj39S5Rz2FlDDV',
#   'https://class101.net/products/iy5i270NDFNxiEd1OMDn',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/Otmgd0tIQJuPgVpitLhU',
#   'https://class101.net/products/QpX43F2QMPLZDbHOJU6L',
#   'https://class101.net/products/LT0H8FAjCjICCpJvoADR',
#   'https://class101.net/products/5T4IxMiHokMgrNBSIV1T',
#   'https://class101.net/products/XPnvdRSAzYMYaJ8o0aGb',
#   'https://class101.net/products/LQ8QCbf39IgWXrWK24YO',
#   'https://class101.net/products/bFSTbFljZ3R1SOPaXK1l',
#   'https://class101.net/products/lqXzLSU0CjINUl0DDhSq',
#   'https://class101.net/products/BgLKl53Z5Gc3LOrzGnHj',
#   'https://class101.net/products/mZxyOTrCjLmdkGni10Hu',
#   'https://class101.net/products/YVfKhCr7K9mS69y48lvs',
#   'https://class101.net/products/Wq5aBT02NmxYdpdwuXbf',
#   'https://class101.net/products/f6KtL54kNeGxfA9IDsK6',
#   'https://class101.net/products/1YUtxPBHb7jwmPVGrdNq',
#   'https://class101.net/products/hxehoorQf5xbxXK4MsOi',
#   'https://class101.net/products/SuC7g4unbHX10YnjNiFP',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/Ha3AEzrtwl2RxXjjmpid',
#   'https://class101.net/products/LT0H8FAjCjICCpJvoADR',
#   'https://class101.net/products/QpX43F2QMPLZDbHOJU6L',
#   'https://class101.net/products/Otmgd0tIQJuPgVpitLhU',
#   'https://class101.net/products/u3tXP8Wvz2DIWB0E5xVL',
#   'https://class101.net/products/m88NZ3qdFzAg2hHDbkwy',
#   'https://class101.net/products/w7lAcHYx3RYuBCGykIoH',
#   'https://class101.net/products/2R71QlOwxRq83dmXhOnk',
#   'https://class101.net/products/kt0eQzZJKlIL4NESbdqd',
#   'https://class101.net/products/IsuucrmPvI03ujdnpEfB',
#   'https://class101.net/products/iEShQk7jm9UqC2AA2NGt',
#   'https://class101.net/products/1rQ7q3dNwnVCIqGtdAOn',
#   'https://class101.net/products/IV0CGre7RKTVCpJX3p0E',
#   'https://class101.net/products/FiPQcs8iwCYgMzfEnUwh',
#   'https://class101.net/products/qmNEx8kjiSG9ECZVKNy4',
#   'https://class101.net/products/9VvFv8hwkkPPcxK4GzuM',
#   'https://class101.net/products/y1Wm9IcpJb7UyP7CTz6D',
#   'https://class101.net/products/hgsRnnZ2DFgdHWsn7doq',
#   'https://class101.net/products/e8DBpMLGQRKStLCUpcWn',
#   'https://class101.net/products/2z6xfLAReIjpToK9mffq',
#   'https://class101.net/products/RLPQ6q1IBjylKDhnDYfT',
#   'https://class101.net/products/udOxzzIfjUPTLYQo23gq'],
#  ['https://class101.net/products/46XGCJBSgZ9kkLVfnxXg',
#   'https://class101.net/products/gray',
#   'https://class101.net/products/0384462CF31FEA26AF51A2',
#   'https://class101.net/products/zRhHZc5JwFkJgcafCJiY',
#   'https://class101.net/products/7FVmZW619IUBtp7aLFVE',
#   'https://class101.net/products/g0rAQrSJkSLzhlRyOLvS',
#   'https://class101.net/products/vqfIQU3gyszpyfR5i2D2',
#   'https://class101.net/products/boycold',
#   'https://class101.net/products/jfs-mastering',
#   'https://class101.net/products/paloalto']]

# %%
new = []
top = []
for i in a:
    print(len(i))
    for j in range(len(i)):
        if j<10:
            top.append(i[j])
        else:
            new.append(i[j])
# Out:
# 30
# 30
# 30
# 132
# 10

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
len(new)
# Out:
# 182

# %%
                
topdf = pd.DataFrame(top)
newdf = pd.DataFrame(new)

topdf.to_csv("toplinks.csv")
newdf.to_csv("newlinks.csv")

# %%
# for i in top:
#     print(i)
print(len(top))
# Out:
# 30

# %%
# for i in new:
#     print(i)
print(len(new))
# Out:
# 60

# %%
topdf = pd.DataFrame(top)
newdf = pd.DataFrame(new)

topdf.to_csv("toplinks.csv")
newdf.to_csv("newlinks.csv")

# %%
b
# Out:
# ['https://class101.net/creative',
#  'https://class101.net/money',
#  'https://class101.net/career']

# %% [markdown]
# ## Lets extract the 100 link of infinite scroll products

# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
# Out:
# ['https://class101.net/creative',
#  'https://class101.net/money',
#  'https://class101.net/career']

# %%
urls = pd.read_csv('parent_links.csv')
all_links = []

target = list(urls["0"])
tt = target[:3]
all_links = []

for i in range(len(tt)):
    href = []
    url = tt[i]
    def scroll(url):
        driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')
        scroll_pause_time = 5
        print(url)
        driver.get(url)
        time.sleep(3)

        print("Scrolling...", end ="\n")
        while True:
            last_height = driver.execute_script("return document.body.scrollHeight")
    #         # Get scroll height
            print("Last height ", last_height)

            # Wait to load page
            print('while...')

            source_code = driver.page_source
            soup = BeautifulSoup(source_code, 'html.parser')
            infinitediv = soup.find_all("div", class_=['SectionWithInfiniteScrollGridList__Content-sc-1b8v326-0', 'exzfmE'])
            infItems = []

            for y in infinitediv:
                infItems.append(y.find_all('a', class_ = ['ProductCardWithLastUpdatedInformationfragment__HoverStyledLink-sc-146ouht-0', 'hVwDSX']))

            for yy in infItems:
                for yyy in yy:
                    if len(href) < 100:
                        if base+yyy.attrs['href'] not in href:
                            href.append(base+yyy.attrs['href'])
                            print("Len href",len(href))

            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3)
            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            print("New height ", new_height)

            if (len(href) > 100) or (new_height == last_height):
                print("Quiting")
                driver.quit()
                break
            last_height = new_height  
        print("LENGTH href :",len(href))
        all_links.append(href)
        return
    scroll(url)
    
final_links = []
for i in all_links:
    for j in i:
        final_links.append(j) 
len(final_links)
linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")

linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")
# Out:
# https://class101.net/creative
# Scrolling...
# Last height  5359
# while...
# Len href 1
# Len href 2
# Len href 3
# Len href 4
# Len href 5
# Len href 6
# Len href 7
# Len href 8
# Len href 9
# Len href 10
# Len href 11
# Len href 12
# Len href 13
# Len href 14
# Len href 15
# Len href 16
# Len href 17
# Len href 18
# Len href 19
# Len href 20
# Len href 21
# Len href 22
# Len href 23
# Len href 24
# Len href 25
# Len href 26
# Len href 27
# Len href 28
# New height  7636
# Last height  7636
# while...
# Len href 29
# Len href 30
# Len href 31
# Len href 32
# Len href 33
# Len href 34
# Len href 35
# Len href 36
# Len href 37
# Len href 38
# Len href 39
# Len href 40
# Len href 41
# Len href 42
# Len href 43
# Len href 44
# Len href 45
# Len href 46
# Len href 47
# Len href 48
# Len href 49
# Len href 50
# Len href 51
# Len href 52
# Len href 53
# New height  9588
# Last height  9588
# while...
# Len href 54
# Len href 55
# Len href 56
# Len href 57
# Len href 58
# Len href 59
# Len href 60
# Len href 61
# Len href 62
# Len href 63
# Len href 64
# Len href 65
# Len href 66
# Len href 67
# Len href 68
# Len href 69
# Len href 70
# Len href 71
# Len href 72
# Len href 73
# Len href 74
# Len href 75
# Len href 76
# Len href 77
# Len href 78
# New height  11541
# Last height  11541
# while...
# Len href 79
# Len href 80
# Len href 81
# Len href 82
# Len href 83
# Len href 84
# Len href 85
# Len href 86
# Len href 87
# Len href 88
# Len href 89
# Len href 90
# Len href 91
# Len href 92
# Len href 93
# Len href 94
# Len href 95
# Len href 96
# Len href 97
# Len href 98
# Len href 99
# Len href 100
# New height  13493
# Last height  13493
# while...
# New height  15771
# Last height  15771
# while...
# New height  17723
# Last height  17723
# while...
# New height  19675
# Last height  19675
# while...
# New height  21627
# Last height  21627
# while...
# New height  23905
# Last height  23905
# while...
# New height  25857
# Last height  25857
# while...
# New height  27810
# Last height  27810
# while...
# New height  29762
# Last height  29762
# while...
# New height  32040
# Last height  32040
# while...
# New height  33992
# Last height  33992
# while...
# New height  35944
# Last height  35944
# while...
# New height  37897
# Last height  37897
# while...
# New height  40174
# Last height  40174
# while...
# New height  42127
# Last height  42127
# while...
# New height  44079
# Last height  44079
# while...
# New height  46031
# Last height  46031
# while...
# New height  48309
# Last height  48309
# while...
# New height  50261
# Last height  50261
# while...
# New height  52213
# Last height  52213
# while...
# New height  54166
# Last height  54166
# while...
# New height  56443
# Last height  56443
# while...
# New height  58395
# Last height  58395
# while...
# New height  60348
# Last height  60348
# while...
# New height  62300
# Last height  62300
# while...
# New height  64578
# Last height  64578
# while...
# New height  66530
# Last height  66530
# while...
# New height  68482
# Last height  68482
# while...
# New height  70434
# Last height  70434
# while...
# New height  70434
# Quiting
# LENGTH href : 100
# https://class101.net/money
# Scrolling...
# Last height  5789
# while...
# Len href 1
# Len href 2
# Len href 3
# Len href 4
# Len href 5
# Len href 6
# Len href 7
# Len href 8
# Len href 9
# Len href 10
# Len href 11
# Len href 12
# Len href 13
# Len href 14
# Len href 15
# Len href 16
# Len href 17
# Len href 18
# Len href 19
# Len href 20
# Len href 21
# Len href 22
# Len href 23
# Len href 24
# Len href 25
# Len href 26
# Len href 27
# Len href 28
# New height  8066
# Last height  8066
# while...
# Len href 29
# Len href 30
# Len href 31
# Len href 32
# Len href 33
# Len href 34
# Len href 35
# Len href 36
# Len href 37
# Len href 38
# Len href 39
# Len href 40
# Len href 41
# Len href 42
# Len href 43
# Len href 44
# Len href 45
# Len href 46
# Len href 47
# Len href 48
# Len href 49
# Len href 50
# Len href 51
# Len href 52
# Len href 53
# Len href 54
# Len href 55
# New height  10344
# Last height  10344
# while...
# Len href 56
# Len href 57
# Len href 58
# Len href 59
# Len href 60
# Len href 61
# Len href 62
# Len href 63
# Len href 64
# Len href 65
# Len href 66
# Len href 67
# Len href 68
# Len href 69
# Len href 70
# Len href 71
# Len href 72
# Len href 73
# Len href 74
# Len href 75
# Len href 76
# Len href 77
# Len href 78
# Len href 79
# Len href 80
# Len href 81
# Len href 82
# New height  12621
# Last height  12621
# while...
# Len href 83
# Len href 84
# Len href 85
# Len href 86
# Len href 87
# Len href 88
# Len href 89
# Len href 90
# Len href 91
# Len href 92
# Len href 93
# Len href 94
# Len href 95
# Len href 96
# Len href 97
# Len href 98
# Len href 99
# Len href 100
# New height  14574
# Last height  14574
# while...
# New height  14574
# Quiting
# LENGTH href : 100
# https://class101.net/career
# Scrolling...
# Last height  5359
# while...
# Len href 1
# Len href 2
# Len href 3
# Len href 4
# Len href 5
# Len href 6
# Len href 7
# Len href 8
# Len href 9
# Len href 10
# Len href 11
# Len href 12
# Len href 13
# Len href 14
# Len href 15
# Len href 16
# Len href 17
# Len href 18
# Len href 19
# Len href 20
# Len href 21
# Len href 22
# Len href 23
# Len href 24
# Len href 25
# Len href 26
# Len href 27
# Len href 28
# New height  7636
# Last height  7636
# while...
# Len href 29
# Len href 30
# Len href 31
# Len href 32
# Len href 33
# Len href 34
# Len href 35
# Len href 36
# Len href 37
# Len href 38
# Len href 39
# Len href 40
# Len href 41
# Len href 42
# Len href 43
# Len href 44
# Len href 45
# Len href 46
# Len href 47
# Len href 48
# Len href 49
# Len href 50
# Len href 51
# Len href 52
# Len href 53
# Len href 54
# Len href 55
# Len href 56
# New height  9914
# Last height  9914
# while...
# Len href 57
# Len href 58
# Len href 59
# Len href 60
# Len href 61
# Len href 62
# Len href 63
# Len href 64
# Len href 65
# Len href 66
# Len href 67
# Len href 68
# Len href 69
# Len href 70
# Len href 71
# Len href 72
# Len href 73
# Len href 74
# Len href 75
# Len href 76
# Len href 77
# Len href 78
# Len href 79
# Len href 80
# Len href 81
# Len href 82
# Len href 83
# Len href 84
# New height  12191
# Last height  12191
# while...
# Len href 85
# Len href 86
# Len href 87
# Len href 88
# Len href 89
# Len href 90
# Len href 91
# Len href 92
# Len href 93
# Len href 94
# Len href 95
# Len href 96
# Len href 97
# Len href 98
# Len href 99
# Len href 100
# New height  14469
# Last height  14469
# while...
# New height  16747
# Last height  16747
# while...
# New height  19024
# Last height  19024
# while...
# New height  19686
# Last height  19686
# while...
# New height  19686
# Quiting
# LENGTH href : 100

# %%
len(all_links)
# Out:
# 3

# %%
final_links = []
for i in all_links:
    for j in i:
        final_links.append(j) 
linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")
# Out:
# 300

# %%
final_links
# Out:
# ['https://class101.net/products/JIGdVpbXb0NxReO0kDd7',
#  'https://class101.net/products/WF9WMczr3eaNSmNKdsrd',
#  'https://class101.net/products/syl2thdl6OnZVINRaHGI',
#  'https://class101.net/products/60k8GonVAcVLurC3gLdX',
#  'https://class101.net/products/9fp7JldIX9SqISLIk3VO',
#  'https://class101.net/products/wTNYQrZ6QJuUrQwWbiP2',
#  'https://class101.net/products/WRtHxKybtbd6sTSLeNfG',
#  'https://class101.net/products/0rClhrw0ljNFZMwycbJ6',
#  'https://class101.net/products/cNj6pGVqWYSgAYHhx5L6',
#  'https://class101.net/products/kGtI3fY2gupwYBiIz60V',
#  'https://class101.net/products/yOhNtoQsxcIrcUjzzum1',
#  'https://class101.net/products/RcYLlJSDFDql12cpZOrU',
#  'https://class101.net/products/zohzMKZTVrMjiJRNOMGh',
#  'https://class101.net/products/LrQikfox2u5ay0YCvNMr',
#  'https://class101.net/products/mQ6k4de6ROHU1hAUx2xj',
#  'https://class101.net/products/1s2GyEtRBb2q31HNEIY7',
#  'https://class101.net/products/PztTLLGW8jwzFpYhZxva',
#  'https://class101.net/products/UhIOQOMvljRwQbji8Wrr',
#  'https://class101.net/products/YT8uqzpEoNqzxOdOo9BE',
#  'https://class101.net/products/XfXQYt5h0edCw8qjtlYI',
#  'https://class101.net/products/taAqhVz62rYVn7JFZYY7',
#  'https://class101.net/products/6zymWqgESI5vlAS8XGVv',
#  'https://class101.net/products/WhSpqO9qMxOq9Zaf0DxV',
#  'https://class101.net/products/eugSN5jN2jnHQllDrpqK',
#  'https://class101.net/products/dL3fp94Y8GfKV8qpByoL',
#  'https://class101.net/products/VmoWMd46c14txZUYrRpd',
#  'https://class101.net/products/GhtexWWAXlFVvOZVYfGt',
#  'https://class101.net/products/FMNJejjTMSCwxHdvwXz8',
#  'https://class101.net/products/yVL6ucPDrcjSjxaWWQoF',
#  'https://class101.net/products/SvIQLOksd7kNWoyqMyGN',
#  'https://class101.net/products/MeWbxFNvpDjWA67CWylo',
#  'https://class101.net/products/hpQCJqu7gScxXIYec937',
#  'https://class101.net/products/r4Qwy2ro3YXFDPhHnMbF',
#  'https://class101.net/products/Vcvhx5GDTkJIiUm13oXA',
#  'https://class101.net/products/KSsPGW9m9IxJ0kk231zp',
#  'https://class101.net/products/GiNaDZwgU9Nyrr15nfmm',
#  'https://class101.net/products/i0XwFMVipOTG17rDuS8P',
#  'https://class101.net/products/cUCJ00LPDEVUEWMSJ7aX',
#  'https://class101.net/products/P4W0gjacGKNBY9KBlLg5',
#  'https://class101.net/products/6vzDIxs8V3VzNj2xevMS',
#  'https://class101.net/products/2XmAanyYa7IuDNqtPyve',
#  'https://class101.net/products/WSbm0jnqkNS0SHyVesna',
#  'https://class101.net/products/XoR7zPypDOEONtFS8J6M',
#  'https://class101.net/products/J0v3vURVPHgRqFSB5LxT',
#  'https://class101.net/products/IkmJ4SYQNlgb1w0WmRMt',
#  'https://class101.net/products/NclIv9AFqlMde6NO3USE',
#  'https://class101.net/products/XyobuAE6Z0DpkvJheH8F',
#  'https://class101.net/products/UfqS8oIz0cYPkbyclNdm',
#  'https://class101.net/products/hf3H7C5T96VByVsA3ZRz',
#  'https://class101.net/products/z01gOi4ISxB8TbpJJ5Qs',
#  'https://class101.net/products/XPveiQI6bHmz65ms7FVm',
#  'https://class101.net/products/eiJsxjGfM2s7tNMz5L7K',
#  'https://class101.net/products/jPc5Xr7XHhLBk9JxFyFq',
#  'https://class101.net/products/GJRYUN4qZx1ysKXYJZ8c',
#  'https://class101.net/products/mfwAozYuRSRgmcRezhlr',
#  'https://class101.net/products/yeQnRSaP2pqo745N7mGS',
#  'https://class101.net/products/GK5zegrxlJqsIVhUaZRL',
#  'https://class101.net/products/S5oUiefI5TBm8bHy8Hfb',
#  'https://class101.net/products/tM1lCXRFBFkAdY7VFIDv',
#  'https://class101.net/products/M4vHw0vAk1u8oPIV3gV5',
#  'https://class101.net/products/ZL0vBjnSjxZXV5kfbfur',
#  'https://class101.net/products/NYvT2wOgjRFc3fHh9EWe',
#  'https://class101.net/products/0RaIaMhZOIo5qxcKo2CO',
#  'https://class101.net/products/cBx2SzgyzsqePDc0uSEO',
#  'https://class101.net/products/appi2asmnnurRpIJygIt',
#  'https://class101.net/products/mkMB42fapEiT03Ql9SAD',
#  'https://class101.net/products/VCgFENneJ7RgkELnBnlv',
#  'https://class101.net/products/retroromance-painting',
#  'https://class101.net/products/Ntb24i5h8F7D2l2MqmhI',
#  'https://class101.net/products/m5mkfdBxKgQn0M5DbpQO',
#  'https://class101.net/products/zLSkcce773cmD6rsSRFP',
#  'https://class101.net/products/jQGSNyoqxPCRg2e2HMl6',
#  'https://class101.net/products/sX8qjwMVWC2XNg3Oysm5',
#  'https://class101.net/products/G5CUnoC8AEpNEHhBRkaY',
#  'https://class101.net/products/r6u5BnYN3A7OLZ7X1XYu',
#  'https://class101.net/products/ZLJyYWqrnxgziD56Paiw',
#  'https://class101.net/products/vCJPaLfZcy6Br1yjhaao',
#  'https://class101.net/products/hMyDgEG8BKy9F9SN1npx',
#  'https://class101.net/products/ENppV01t0eGcUoEl1TYq',
#  'https://class101.net/products/2ovRL2WGqGW2tKtXDQOS',
#  'https://class101.net/products/gPjiSJfMSI6EN6C49vji',
#  'https://class101.net/products/kIgvjnvj4tlpxOATOvXm',
#  'https://class101.net/products/hSH0xsslKokfObAy84i3',
#  'https://class101.net/products/DF0TjwMIB6h9ETJPuuiw',
#  'https://class101.net/products/RMyRDdRoJpJocacI3EtI',
#  'https://class101.net/products/9jJDEbYikRBIbEN9BlqM',
#  'https://class101.net/products/7HOmU1C4REEGY9NpDiAL',
#  'https://class101.net/products/LD018tDYv5ZvUClkuA5L',
#  'https://class101.net/products/1KmyRi1nhrSqdMYIs4VN',
#  'https://class101.net/products/HD8CnHis5L9kqvq42SJj',
#  'https://class101.net/products/Q3Q6eIydgM4jZZdYuQZr',
#  'https://class101.net/products/WT3DtXVPzSh0oI8TtXwA',
#  'https://class101.net/products/MsbVkx56JxutdRmnicny',
#  'https://class101.net/products/YNB7FVI4kdmvYUIxUlrf',
#  'https://class101.net/products/xmfrADxK0LP73uFaT0y0',
#  'https://class101.net/products/QKw8hXqf50TCyrdEsp2R',
#  'https://class101.net/products/MyT0d7qvKYg6CYBDERic',
#  'https://class101.net/products/kipaKvlUw1ZbRY6akCsy',
#  'https://class101.net/products/pXzd6Kpt7gyuFyb5R2Qh',
#  'https://class101.net/products/DfXsZX1ylOX3A9xavPaO',
#  'https://class101.net/products/SwUgMr0MDAPXSPgLsD01',
#  'https://class101.net/products/vXcO1iZbdpyZoLH2Aq4S',
#  'https://class101.net/products/h5FwB3mlXd9Z0zwMMQtt',
#  'https://class101.net/products/swiCy104cJKb55nooZ27',
#  'https://class101.net/products/8NTUxCwCa3jf3NVbFQ6Z',
#  'https://class101.net/products/ZQh656roDLZnsLSmxhWs',
#  'https://class101.net/products/gTMaIPskP1BRMcP2oSe0',
#  'https://class101.net/products/KPPdqrZv7ZQ6CrDU0VVa',
#  'https://class101.net/products/yvivFBDvXqRYaZfawhdK',
#  'https://class101.net/products/3aGZnRt6i9pdS2m6NTYr',
#  'https://class101.net/products/bdR7LQXYc6yhJ9ZqqvuL',
#  'https://class101.net/products/hZG3Mclh6BamJIDoSU95',
#  'https://class101.net/products/D49lZMhChAFpYXhGAlZg',
#  'https://class101.net/products/PH5YxomvF2NSVkCxvJO2',
#  'https://class101.net/products/nyULkfIF1oH6kPNAPSLE',
#  'https://class101.net/products/fBcuqxuLShuEZXVFNfHV',
#  'https://class101.net/products/M7QbyoAue23dUEutSPtn',
#  'https://class101.net/products/pHIZchR7a0C5hMpVvnp5',
#  'https://class101.net/products/O7SGv57YJ6mzaQerZjaS',
#  'https://class101.net/products/Xl3FzgGJCzgid7nsKIjE',
#  'https://class101.net/products/kl0DdlkkXGyssJdqUHeK',
#  'https://class101.net/products/JSuU0LhLMQK9KSzIz1JK',
#  'https://class101.net/products/zaswQi8tonzayH30fpDq',
#  'https://class101.net/products/E9jfiX9nAaq5ZwGjOJLY',
#  'https://class101.net/products/B84vroykY9vgJsgxGTjU',
#  'https://class101.net/products/GNNMfyIfdxmlByRtMbdI',
#  'https://class101.net/products/HOEqb85vLfEvGxEXlepL',
#  'https://class101.net/products/hoLSB5FdepaYtLrm6zZw',
#  'https://class101.net/products/bM6mHt511x3FAaF5d1bH',
#  'https://class101.net/products/uKiVg18hblAXS4uxZMKK',
#  'https://class101.net/products/0OJpXesBG3iQhxwNhSf0',
#  'https://class101.net/products/p4twM02W81uWdC5vAKrn',
#  'https://class101.net/products/6JEEdjUieqshYeSb7ALy',
#  'https://class101.net/products/mK9mAfPGPKbSkT4ROTNq',
#  'https://class101.net/products/20wWVPynXYH3Bl6r97sY',
#  'https://class101.net/products/goGqTm0oudZOWk4NT3ZW',
#  'https://class101.net/products/OYIe1e00fBassOK74AMi',
#  'https://class101.net/products/w4aPU5t9U4eaCr0vrL5l',
#  'https://class101.net/products/zyzx4oWNJw7KtzrI1QuA',
#  'https://class101.net/products/pf5MCuQ1lKwzRcAlKWT9',
#  'https://class101.net/products/k3KP0Kh69A8iWMTihVuZ',
#  'https://class101.net/products/AYrAD4ISUccARLyFtv7b',
#  'https://class101.net/products/ByhIvObQacUKvTHCorCN',
#  'https://class101.net/products/0GavpYVoznvU9tUjttee',
#  'https://class101.net/products/2cHsOhvp6DX1P6T0lvNU',
#  'https://class101.net/products/Q0hMx8kzjfSUoL5Iijam',
#  'https://class101.net/products/fINpivvXH1bOjgCjJuRd',
#  'https://class101.net/products/rt0QWKuoPY4lH2UfKF6b',
#  'https://class101.net/products/G4bSyvLzuiOMViUHmsAc',
#  'https://class101.net/products/yNr1JKLAIOSfH2qKFDMQ',
#  'https://class101.net/products/qxi8YndiWKOmLD3smv45',
#  'https://class101.net/products/dXuXpvNQyGbYAQbJ1xsa',
#  'https://class101.net/products/2LBNjOdkf1Ip7Fsvv8CA',
#  'https://class101.net/products/aUEkjwER2dFjrEZNEpWW',
#  'https://class101.net/products/DZpP1fzSjtL57kY1dQl0',
#  'https://class101.net/products/9Pr1wfBLzT482gLlgynR',
#  'https://class101.net/products/t4Hd40M9hjRMGLsBFL4H',
#  'https://class101.net/products/uEBzVly2IVJ2CEx4sDQr',
#  'https://class101.net/products/l3SxzjiSe3AnA6ilD1h0',
#  'https://class101.net/products/94ActB4yrmehhtV8EU3k',
#  'https://class101.net/products/c8seZ48pAQM8OE2kV3sO',
#  'https://class101.net/products/SdJYB9PEhta0J80zc2WC',
#  'https://class101.net/products/NXXY8aOwhSLbHb77NFul',
#  'https://class101.net/products/k18sYqFPhzGrIvyLUmfa',
#  'https://class101.net/products/j2cqasKulOEI8EtcgWmd',
#  'https://class101.net/products/W3c5CNsjC6WDyMAU5Le3',
#  'https://class101.net/products/xLhiDKT5DfsMTqUIRIQj',
#  'https://class101.net/products/1iaqYuOWPJAN69tbwctR',
#  'https://class101.net/products/9qhpATqcUDcaOHrep6AY',
#  'https://class101.net/products/AKwX4czUR18hIyk1A8gk',
#  'https://class101.net/products/LDsDoEsreKNcS6GUq3H1',
#  'https://class101.net/products/nE3Rka3C8quVUg6sJTXu',
#  'https://class101.net/products/tc4HO2QBtuOlHPYWUILG',
#  'https://class101.net/products/QlSYza1dgzP9IwaPmP2Q',
#  'https://class101.net/products/ahZk6lmlzJqhUhdPzjxm',
#  'https://class101.net/products/6Us6lRjSGtRZ29LEQUgN',
#  'https://class101.net/products/BEs4zGb3nC7GoNhvFlYd',
#  'https://class101.net/products/JViNFMqAETG4rdq5RDm2',
#  'https://class101.net/products/BjkCb7AJ62j1x7nZ0yaM',
#  'https://class101.net/products/HQrpOdQLDnL4Pw0OZy36',
#  'https://class101.net/products/snM41CNvsKuNsqjyz4EO',
#  'https://class101.net/products/pwwRVAbXAZHvkYohgAyH',
#  'https://class101.net/products/vypjq3fD3nXUumomKbKU',
#  'https://class101.net/products/DNm9e65tB7fmFQ78cOPz',
#  'https://class101.net/products/1IjkPkchXqXW6YfofbB1',
#  'https://class101.net/products/UnwUN7uIbCynOCajdipU',
#  'https://class101.net/products/BXeLjjdAgueyv0WawptA',
#  'https://class101.net/products/x46N7k3Czm28tD70c3Xb',
#  'https://class101.net/products/xC20zjTXOU1fhT12lrKj',
#  'https://class101.net/products/it09WToirhHle4VvH7VB',
#  'https://class101.net/products/PYMT6APnZ0Tsbc4cMZly',
#  'https://class101.net/products/yM5xIeMKeEZ2LkAkLf0f',
#  'https://class101.net/products/nuoIiwtPPmyhVZRN2ABV',
#  'https://class101.net/products/MgIGaBM7jsRJI60Vqrq4',
#  'https://class101.net/products/h8K990eaOU1UisdL4jH4',
#  'https://class101.net/products/CN4cRcW2pvlRyb85RpeP',
#  'https://class101.net/products/mVAFyZcEnDTSLDVylpsF',
#  'https://class101.net/products/7G7DoY730RGV6hfVGaI1',
#  'https://class101.net/products/1RosxvekE3qFVmvibOFp',
#  'https://class101.net/products/daxSCmVcskQEKjGoU1tm',
#  'https://class101.net/products/yDF06KBZ1b3uHbXwHOD2',
#  'https://class101.net/products/zER07XgAd3qkOxl3x1oA',
#  'https://class101.net/products/2lBCODLFYI7gJkyAKNEN',
#  'https://class101.net/products/ssvJ8xm8Hu9DNE80x37x',
#  'https://class101.net/products/bsIL14Gpj2bZ0lG0Bz2o',
#  'https://class101.net/products/ZR3MP6PWrpCFJDy32E7H',
#  'https://class101.net/products/OWXndRN1fzytZU5fGAGN',
#  'https://class101.net/products/5RcUZlcjCDVulejewYvU',
#  'https://class101.net/products/0khf0PHxnnbi5xHQc7G8',
#  'https://class101.net/products/heQl6vZQkkWeSkrDhsuf',
#  'https://class101.net/products/zQzL4YfRU9b3TXH9XIaC',
#  'https://class101.net/products/X02G2UW01H6yt5pcHEi4',
#  'https://class101.net/products/gv6EaDQHgJSGPDw0jEbO',
#  'https://class101.net/products/zeRwvHdzx0D3YsoLvPQ9',
#  'https://class101.net/products/suWmiRVU7556OZJeVpGK',
#  'https://class101.net/products/oA1xFQg36RVNHDBPhiUH',
#  'https://class101.net/products/Nl3FICmR5yj9gDBY3JHt',
#  'https://class101.net/products/DPoZd4DROSlUcNxYSVlx',
#  'https://class101.net/products/gFa0KoITX15Z0ISIuPjP',
#  'https://class101.net/products/pucWCh3gdO6ADMgYpNNY',
#  'https://class101.net/products/4rb9WsmLEP9s9aXtlwIo',
#  'https://class101.net/products/RO7THQA5Y4eF4iHmdvPd',
#  'https://class101.net/products/nLTf6U6abiqJp7eFZclT',
#  'https://class101.net/products/FLZYimDPbIYbQNjXbBL7',
#  'https://class101.net/products/jV9VgrbL81PsJ4kkGZnc',
#  'https://class101.net/products/sp2L0a0rbvT0Po31dD8b',
#  'https://class101.net/products/ycTlAkNpT4yijPQEARNQ',
#  'https://class101.net/products/ljrEzV2Yg9qgDqpbsjsm',
#  'https://class101.net/products/oU5yNXIHjzpmyJsyeIMI',
#  'https://class101.net/products/yRB9cKNka4SlPJVhQD6c',
#  'https://class101.net/products/MeUQLCfFwuzKxXkU2e91',
#  'https://class101.net/products/0GHv9wYvBfUXSbdEPS1Q',
#  'https://class101.net/products/W6lee7luBzX7r7zcSQOR',
#  'https://class101.net/products/4kAJt4fDMrVeiNPnJ966',
#  'https://class101.net/products/UCr4cydxaCZxKCyO28Qt',
#  'https://class101.net/products/NB5dmmMr9nmuTX3aCVJi',
#  'https://class101.net/products/BJ6jqqbdjjWP097BqV3H',
#  'https://class101.net/products/tzYia7G0IlcT9AvPm4qk',
#  'https://class101.net/products/po0RnlDQqjZmSqf6Qs11',
#  'https://class101.net/products/Jc2kteYpGUvjZR5QT3GS',
#  'https://class101.net/products/s3Fce0m08mg5tbofkqtt',
#  'https://class101.net/products/vzITnUK9I5BC6J98OI06',
#  'https://class101.net/products/kyUf5Ly1YgfPp5KFcH8k',
#  'https://class101.net/products/9131eDgx0mdOAt8VKlPC',
#  'https://class101.net/products/HqYy7CbUm1E7SdvvT1sh',
#  'https://class101.net/products/7jF8JRyFP6XXl1tzS2UQ',
#  'https://class101.net/products/DL0TUq5muAu3DUdXIJ8P',
#  'https://class101.net/products/rGeYJRGZ1HW1Of2K8jEK',
#  'https://class101.net/products/Rdy01tgOJr6JgM5dTajT',
#  'https://class101.net/products/NEn5qd66nEHaVpqznY3J',
#  'https://class101.net/products/EQSsaPauoSmWnPoDP7ld',
#  'https://class101.net/products/DtxzbUtxBNp3GDm1tAhj',
#  'https://class101.net/products/NsCdQi8TezSVzUP7rcOA',
#  'https://class101.net/products/LZAZUXDzMoShLGBX6BAP',
#  'https://class101.net/products/kSa7H0nxsl63s7kXAT3D',
#  'https://class101.net/products/kl030syt2F2bLPRu1e61',
#  'https://class101.net/products/QDnu5PUZtAXYRivB7nyK',
#  'https://class101.net/products/xVYqd2NYQ5KIfx3Hyh0y',
#  'https://class101.net/products/frsqaRHmeWDTZwvy0yBt',
#  'https://class101.net/products/xYzEJ7cXkumFGexsdAI6',
#  'https://class101.net/products/euWprzr7oOp0CpidXfEF',
#  'https://class101.net/products/tk9ZcndBfpAWMkcSuln9',
#  'https://class101.net/products/cuqnpEBt2YMfOQkp9Srw',
#  'https://class101.net/products/pBKPi79NrvxlEdy85pGG',
#  'https://class101.net/products/v4DDTPyI5vwh6vawSJe2',
#  'https://class101.net/products/bcmkBxBBWG7dqfBZ9iUt',
#  'https://class101.net/products/ysovxMyT45Uc7BJf18An',
#  'https://class101.net/products/uaX5abXZPoDB1u3iSgQ8',
#  'https://class101.net/products/k9xWqy3cxkMeOhavGLBZ',
#  'https://class101.net/products/eoRWV33KBKEx8hJwX0mI',
#  'https://class101.net/products/PqxdYHXMc1QCkCvGEBku',
#  'https://class101.net/products/vrDkUoBda59pQ5uGX9ex',
#  'https://class101.net/products/bkI6wZjAHcxoWC4aOy0M',
#  'https://class101.net/products/sVojNzLEQ2hHM99g8Qun',
#  'https://class101.net/products/pu6vt4j5zbkwarzJQKJS',
#  'https://class101.net/products/nvvjAvh2facn37DVO611',
#  'https://class101.net/products/z1BZTzJF8figBHGV5qT3',
#  'https://class101.net/products/F6xgvoP9kluwjSvpHkV5',
#  'https://class101.net/products/dgcMHbY1voFDU9vCeEsX',
#  'https://class101.net/products/W7BUgJbuJDbuLWAv4arf',
#  'https://class101.net/products/Y03u39WRBKEh2gUBU2vR',
#  'https://class101.net/products/AFvjSgVZ9h9qWZHASOS3',
#  'https://class101.net/products/lr9bPDzdMjqmv8rn4yMu',
#  'https://class101.net/products/vfU6Ngy8gwmP2MA8vx06',
#  'https://class101.net/products/YsNqf8So7bTGhglgLO88',
#  'https://class101.net/products/Dip9O8ikht5Yhdc2C1FQ',
#  'https://class101.net/products/cozHiLlSR7XXYl40dtWo',
#  'https://class101.net/products/eYBZ84t6NlcSaj7kaiYk',
#  'https://class101.net/products/vTjLq98ER90iEgEn5XXf',
#  'https://class101.net/products/FbJgy1404m03mKgf4L1j',
#  'https://class101.net/products/TX8KPYb1lr2fA68Akeax',
#  'https://class101.net/products/bS0ca4DEOjqJF82AR4jo',
#  'https://class101.net/products/cZ1bfvEZyjMj3CZVTzpf',
#  'https://class101.net/products/in1XXV65pI2HESEoqnxd',
#  'https://class101.net/products/gF22nCgUNsOTfwwSumfM',
#  'https://class101.net/products/UukNd9aO7PoDgEPS8bux',
#  'https://class101.net/products/wPu76qt8487qi1ItCR1E',
#  'https://class101.net/products/1K0BJoABe48TwjGwLiIJ',
#  'https://class101.net/products/pqQNWaOfSVq6RVNAkylI',
#  'https://class101.net/products/XwNFvAxss1icQQS2I1RQ']

# %%
final_links = []
for i in all_links:
    for j in i:
        final_links.append(j) 
len(final_links)
linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")

linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")

# %% [markdown]
# # Lets load dataframes for extracting data

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

t = pd.read_csv("toplinks.csv")
t = t.drop(['Unnamed: 0'], axis = 1)
t = list(t["0"])

n = pd.read_csv("newlinks.csv")
n = n.drop(['Unnamed: 0'], axis = 1)
n = list(n["0"])

alll = pd.read_csv("alllinks.csv")
alll = alll.drop(['Unnamed: 0'], axis = 1)
alll = list(alll["0"])

# %%
len(alll)
# Out:
# 300

# %%
len(t)
# Out:
# 30

# %%
len(n)
# Out:
# 60

# %% [markdown]
# # Lets extract data from each of those

# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time

# %% [markdown]
# ### Top 10

# %% [markdown]
# ### New Arrival

# %% [markdown]
# ### Infinite Product List

# %%
all_item = []

for i in range(1):
    url = n[i]
    item = []
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')
    
    def getdata(url):
        print(url)
        
        driver.get(url)

        # Wait to load page
        print('while...')

        source_code = driver.page_source
        soup = BeautifulSoup(source_code, 'html.parser')

        initial = soup.find_all("div", class_=['sc-dkiTmt', 'cQiUWe'])
        for y in initial:
            initialdiv = y.find_all('div', class_ = ['ProductHeader__Header-az1cmu-0 leqDJG','AffixProductHeader__StyledProductHeader-sc-1l73jdk-1','idfLTb'])
            for p in initialdiv:              
                top2 = p.find_all('div', class_ = ['sc-bdnylx','gGpzAi','ProductHeader__Tag-az1cmu-1','iOzkLq'])
                for k in top2:
                    if k.text not in item:
                        item.append(k.text)

                heading = p.find_all('h2', class_ = ['sc-bdnylx','cOMiUB','ProductHeader__Title-az1cmu-2','fkqBP'])
                for j in heading:
                    if j.text not in item:
                        item.append(j.text)

                recommend = p.find_all('div', class_="SalesProductInfoTable__Row-sc-1uyx5v1-1 gOzdaG")
                for r in recommend:
                    t2 = r.find_all('div', class_ = ['SalesProductInfoTable__ButtonContainer-sc-1uyx5v1-5','jOtFPR','SalesProductInfoTable__StyledExperiment-sc-1uyx5v1-4','diAwWT'])
                    for t in t2:
                        each = t.find_all('button', class_ = ["sc-ksluoS", "dyNqkJ" ,"sc-kfYqjs", "kpPRTM","SalesProductInfoTable__WishlistButton-sc-1uyx5v1-2", "fxUQsM"])
                        for e in each:
                            if e.text not in item:
                                item.append(e.text)
                                
        
        while True:
            last_height = driver.execute_script("return document.body.scrollHeight")
            print("Last height ", last_height)
            
            source_code = driver.page_source
            soup = BeautifulSoup(source_code, 'html.parser')
            
            ########left section
            initial = soup.find_all("div", class_=['sc-dkiTmt', 'cQiUWe'])
            for y in initial:
                left = y.find_all('div', class_ = ['sc-eiQXzm','cSojtf', 'commonStyles__StaticPositionedColumn-sc-6jqw77-1', 'bvouQZ'])
                for l in left:
                    pro = l.find_all('div', class_ = ['commonStyled__ContentArea-sc-17rimc7-0','ACCCm'])
                    for pr in pro:
                        p = pr.find_all('div', class_ = ['sc-dkiTmt','cQiUWe'])

                        #pro heading section
                        for i in p:
                            pi = i.find_all('div', class_ = ['CreatorIntroSection__Title-sc-18c4e1x-0','bdBflQ'])
                            for p in pi:
                                #name section
                                pname = p.find_all('div', class_ = ['sc-bdnylx','jckokO',  'ContentSectionStyle__SectionTitle-sc-1oywcqb-1', "CreatorIntroSection__WordBrokenSectionTitle-sc-18c4e1x-1","iJQLEl" ,"bSBRTB"])
                                for pn in pname:
                                    if pn not in item:
                                        item.append(pn)

                                #link section
                                plink = p.find_all('div', class_ = ['ChannelButtonGroup__Container-sc-1yqg9fu-0','zUbfY'])
                                for pl in plink:
                                    pm = pl.find_all('a', class_ = ['sc-hcmsuR','ARwUf','sc-dlnjPT','sc-fFSRdu','cuIYFB','goHICw'])
                                    for a in pm:
                                        if a.attrs['href'] not in item:
                                            item.append(a.attrs['href'])
                        
                    #pro info section
                    for j in l:  
                        pp = j.find_all('div', class_ = ['ContentSectionStyle__SectionBodyColumn-sc-1oywcqb-3','cNvNAk'])
                        for jj in pp:
                            mm = jj.find_all('div', class_ = ['FoldableContent__Container-eh1nn2-0','lmAXPf'])
                            for j in mm:
                                nn = j.find_all('div', class_ = ['FoldableContent__ViewContainer-eh1nn2-1','jPwmCe'])
                                for jj in nn:
                                    i = jj.find_all('div', class_ = ['FoldableContent__InnerContainer-eh1nn2-2','ionrXH'])
                                    for pp in i:
                                        co = pp.find_all('div', class_ = ['SanitizeHtml__SanitizeHtmlContainer-ldtmln-0','gNRtXt'])
                                        for c in co:
                                            coo = c.find_all('ul')
                                            for nm in coo:
                                                if nm.text not in item:
                                                    item.append(nm.text)

            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            print("New height ", new_height)

            if new_height == last_height:
                print("Quiting")
                driver.quit()
                break
            last_height = new_height
        return
    getdata(url)
    all_item.append(item)
    
item
# Out:
# https://class101.net/products/MeWbxFNvpDjWA67CWylo
# while...
# Last height  8075
# New height  13604
# Last height  13604
# New height  13604
# Quiting
# ['운동 · 스트레칭조이 ',
#  '쿠폰 적용 시',
#  '5개월 할부',
#  '34%',
#  '총 할인액',
#  '콘텐츠 이용권',
#  '준비물 키트',
#  '입문자 대상',
#  "7000명의 오프라인 수강생이 선택한 '스트레칭조이'의 다리찢기 프로젝트",
#  '371',
#  '공유하기',
#  'https://www.instagram.com/stretchjoy',
#  'https://www.youtube.com/channel/UC7jfcWMKdtypYEPPtpRboow?sub_confirmation=1',
#  'https://stretchjoy.modoo.at/?NaPm=ct%3Dki34guqu%7Cci%3Dcheckout%7Ctr%3Dds%7Ctrx%3D%7Chk%3Dad6689d12172428f592cc75d8f824707035a4fd7',
#  '전)에어로빅 체조 선수 한양대학교 생활스포츠과학 학사 한양대학교 스포츠경영학 석사 글로벌 스포츠 경영리서치센터 연구원 쓸모있는몸을만드는 스트레칭 저자 쓸모있는몸을만드는 다리찢기 저자생활체육 지도자 에어로빅 1급 생활체육 지도자 보디빌딩 2급나혼자산다 김지훈배우 담당 스트레칭코치두산 장원준 투수 담당 스트레칭코치']

# %% [markdown]
# # kids and store link extraction

# %%
nt = target[3:]
nt
# Out:
# ['https://class101.net/kids', 'https://class101.net/store']

# %%
for i in range(len(nt)):
    url = nt[1]
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')
    print(url)
    driver.get(url)
    time.sleep(3)

    source_code = driver.page_source
    soup = BeautifulSoup(source_code, 'html.parser')
    initialdiv = soup.find_all("div", class_=["CommonLandingCarouselViewController__Container-sc-1hnowar-0","hsqeAh"])
    for i in initialdiv:
        ii = i.find_all("div", class_=["CommonLandingCarouselViewController__Container-sc-1hnowar-0","hsqeAh"])
        for j in ii:
            jj = j.find_all("div", class_ = ["SectionWithOutSideNavigationCarousel__Content-laj44i-0","cTNIGb"])
            for k in jj:
                kk =  k.find_all("div", class_ = ["swiper-container","OutSideNavigationCarousel2__StyledSwiper-lxp9vi-3", "gnxnIG", "swiper-container-horizontal"])
                for l in kk:
                    ll = l.find_all("div", class_ = "swiper-slide")
                    for a in ll:
                        alink =  a.find_all("a", class_ = ["ProductCardfragment__HoverStyledLink-jvv2ql-0", "lmeJlb"])
                        for al in alink:
                            print(al.attrs['href'])

# %%
urls = pd.read_csv('parent_links.csv')
all_links = []

target = list(urls["0"])
tt = target[:3]
all_links = []

for i in range(len(tt)):
    href = []
    url = tt[i]
    def scroll(url):
        driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')
        scroll_pause_time = 5
        print(url)
        driver.get(url)
        time.sleep(3)

        print("Scrolling...", end ="\n")
        while True:
            last_height = driver.execute_script("return document.body.scrollHeight")
    #         # Get scroll height
            print("Last height ", last_height)

            # Wait to load page
            print('while...')

            source_code = driver.page_source
            soup = BeautifulSoup(source_code, 'html.parser')
            infinitediv = soup.find_all("div", class_=['SectionWithInfiniteScrollGridList__Content-sc-1b8v326-0', 'exzfmE'])
            infItems = []

            for y in infinitediv:
                infItems.append(y.find_all('a', class_ = ['ProductCardWithLastUpdatedInformationfragment__HoverStyledLink-sc-146ouht-0', 'hVwDSX']))

            for yy in infItems:
                for yyy in yy:
                    if len(href) < 100:
                        if base+yyy.attrs['href'] not in href:
                            href.append(base+yyy.attrs['href'])
                            print("Len href",len(href))

            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3)
            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            print("New height ", new_height)

            if (len(href) > 100) or (new_height == last_height):
                print("Quiting")
                driver.quit()
                break
            last_height = new_height  
        print("LENGTH href :",len(href))
        all_links.append(href)
        return
    scroll(url)
    
final_links = []
for i in all_links:
    for j in i:
        final_links.append(j) 
len(final_links)
linkdf = pd.DataFrame(final_links)
linkdf.to_csv("alllinks.csv")
