# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

df = pd.read_csv("links.csv")
df["0"]
li = list(df["0"])
b_url = 'm.kin.naver.com'
base = []
c = []
clist = []
print(len(li))

for i in range(3):
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')  
    url = li[i]
    driver.get(url)
    elem = driver.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'html.parser')
    title = soup.find_all('div', class_="titleSection--1lnfz")

    for j in title:
        c.append(j.find_all("a", class_='titleLink--2BV8L'))
    print(c)
#     eee = []
#     for e in c:
#         for ee in e:
#             eee.append(ee)

#     for each in eee:
#         if "sortType=TIME" in each.attrs['href']:
#             if b_url+each.attrs['href'] not in base:
#                 base.append("https://"+b_url+each.attrs['href'])
        
    driver.quit()
# Out:
# 81
# ...

# %%
len(c)

# %%
# Out:
# ['https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=320&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME',
#  'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=320&online=true&sortType=TIME',
# ...

# %%
df = pd.DataFrame(base)
df.to_csv('Data/Intermediate_links.csv')
# Out:
# ['m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=320&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=129&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=122&online=true&sortType=TIME']

# %% [markdown]
# # Practices

# %%
df = pd.read_csv("links.csv")
df["0"]
li = list(df["0"])
li[33]
# Out:
# 'https://m.kin.naver.com/mobile/expert/category/home?groupCategoryId=150&categoryId=210'

# %%
base = []

for i in range(len(li)):
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')  
    url = li[i]
    driver.get(url)
    elem = driver.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    alink = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[4]/div[1]/div[1]/div/a")
    print(alink)
    base.append(alink.get_attribute('href'))
    print(base)
    driver.quit()
#      soup = BeautifulSoup(source_code, 'html.parser')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1212b6bc364592eed3d90bd653adaf0f", element="0b73c950-e66e-4eec-b5c4-72fe1147e7b2")>
# ['https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME']
# <selenium.webdriver.remote.webelement.WebElement (session="b94386c047e1c814a44d51014a6e4fa0", element="b98f8f6a-868e-4184-87f1-0c9b126e1e79")>
# ['https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME', 'https://m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-a1bfe8d58975> in <module>
#       7     elem = driver.find_element_by_xpath("//*")
#       8     source_code = elem.get_attribute("outerHTML")
# ...

# %%
base
# Out:
# []

# %% [markdown]
# ### testing

# %%
df = pd.read_csv("links.csv")
df["0"]
li = list(df["0"])
li[3]
# Out:
# 'https://m.kin.naver.com/mobile/expert/category/home?groupCategoryId=149&categoryId=129'

# %%
driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')  
base = []  
url = li[2]
driver.get(url)
elem = driver.find_element_by_xpath("//*")
source_code = elem.get_attribute("outerHTML")
soup = BeautifulSoup(source_code, 'html.parser')

# %%
dir(driver)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
# ...

# %%
title = soup.find_all('div', class_="titleSection--1lnfz")
title
# Out:
# [<div class="titleSection--1lnfz"><div class="titleArea--s3-rN"><div class="title--1Yy8N"><span class="titleText--2C27G">지금 상담 가능한 엑스퍼트</span></div><a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;online=true&amp;sortType=TIME"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a></div></div>,
#  <div class="titleSection--1lnfz SubTitle_titleSection--1-ey3"><div class="titleArea--s3-rN"><div class="title--1Yy8N"><span class="titleText--2C27G">많이 본 상담</span></div></div><p class="description--3vW4g">최근 1일 많이 본 상담 상품입니다.</p></div>,
# ...

# %%
len(title)
# Out:
# 5

# %%
c = []
for j in title:
    c.append(j.find_all("a", class_='titleLink--2BV8L'))

# %%
c
# Out:
# [[<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;online=true&amp;sortType=TIME"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>],
#  [],
#  [],
#  [<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;sortType=COUNSELING"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>],
#  []]

# %%
eee = []
for e in c:
    for ee in e:
        eee.append(ee)
        
for each in eee:
    if "sortType=TIME" in each.attrs['href']:
        print(each.attrs['href'])
# Out:
# /mobile/expert/search?itemType=EXPERT&category=320&online=true&sortType=TIME

# %%
for each in eee:
    if "sortType=TIME" in each.attrs['href']:
        print('ok')
# Out:
# ok

# %%
clist = []
for cc in c:
    if len(cc) == 0:
        continue
    else:
        clist.append(cc)

# %%
clist
# Out:
# [[<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;online=true&amp;sortType=TIME"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>],
#  [<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;sortType=COUNSELING"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>]]

# %%
base = 'm.kin.naver.com'

clist = []
for cc in c:
    if len(cc) != 0:
        clist.append(cc)

# %%
clist
# Out:
# [[<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;online=true&amp;sortType=TIME"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>],
#  [<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;sortType=COUNSELING"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>]]

# %%
for ji in clist:
    ji.find_all('a')
# Out:
# [<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;online=true&amp;sortType=TIME"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>]
# [<a class="titleLink--2BV8L" href="/mobile/expert/search?itemType=EXPERT&amp;category=320&amp;sortType=COUNSELING"><span class="linkText--Nm8Me">더보기</span><svg class="iconCircleArrow--oYTT-" height="18" viewbox="0 0 20 20" width="18"><g fill="none" fill-rule="evenodd"><circle cx="10" cy="10" r="9.5" stroke="#DBDBDB"></circle><path d="M6.5 10h6M11 7l3 3-3 3" stroke="#7E96FF" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></g></svg></a>]

# %%
for ii in clist[0]:
    print(base + ii.get('href'))

# %% [markdown]
# ### Testing testing

# %%
# importing the required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

df = pd.read_csv("links.csv")
df["0"]
li = list(df["0"])
li[]
b_url = 'm.kin.naver.com'
base = []
c = []
clist = []


for i in range(3):
    driver = webdriver.Chrome(r'C:\Users\USER\chromedriver_win32\chromedriver.exe')  
    url = li[i]
    driver.get(url)
    elem = driver.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'html.parser')
    title = soup.find_all('div', class_="titleSection--1lnfz")

    for j in title:
        c.append(j.find_all("a", class_='titleLink--2BV8L'))
    eee = []
    for e in c:
        for ee in e:
            eee.append(ee)

    for each in eee:
        if "sortType=TIME" in each.attrs['href']:
            if b_url+each.attrs['href'] not in base:
                base.append(b_url+each.attrs['href'])
        
    driver.quit()

# %%
base
# Out:
# ['m.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=90&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=2&online=true&sortType=TIME',
#  'm.kin.naver.com/mobile/expert/search?itemType=EXPERT&category=320&online=true&sortType=TIME']

# %%
   
#     for cc in c:
#         if len(cc) != 0:
#             clist.append(cc)
                
#     for ii in clist[0]:
#         print(base + ii.get('href'))

# %%
taa = ta.find_all('a')
print(taa)

# %%
alink = driver.find_element_by_xpath("//html/body/div[1]/div/div/div[4]/div[1]/div[1]/div/a")
link = alink.get_attribute('href')
link
# Out:
#   File "<ipython-input-147-64ad0fee65c6>", line 1
#     alink = driver.find_element_by_xpath("//html/body/div[1]/div/div/div[4]/div[1]/div[1]/div/a")link = alink.get_attribute('href')
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
new_url = ta[-1].get('href')
base.append("m.kin.naver.com/" + new_url)
time.sleep(2)

# %%
pp = []
for p in range(len(tdiv)):
    #     pp.append(tdiv[p])
    pp.append(tdiv[p].find_all('a', class_ = "titleLink--2BV8L"))

# %%
pp[-2].get("href")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-128ca6e3b1c9> in <module>
# ----> 1 pp[-2].get("href")
#
# n:\workspace\env\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
pp.find('a', class_ = "titleLink--2BV8L")
pp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-2d69cc9dfa9c> in <module>
# ----> 1 pp.find('a', class_ = "titleLink--2BV8L")
#       2 pp
#
# AttributeError: 'list' object has no attribute 'find'

# %%
 a = driver.find_element_by_xpath("//*/div/div[1]/div/div[1]/div[2]/div[1]/div/a[5]").click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-57-6ef386f1b14b> in <module>
# ----> 1 a = driver.find_element_by_xpath("//*/div/div[1]/div/div[1]/div[2]/div[1]/div/a[5]").click()
#
# n:\workspace\env\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# n:\workspace\env\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...
